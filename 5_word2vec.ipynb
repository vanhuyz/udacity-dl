# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
a = dict()
print(a)
# Out:
# {}

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])

del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3081, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.178864
# Nearest to three: blues, monies, powiat, climber, besieged, fortunate, feasibility, reconstructionist,
# Nearest to if: konkan, kickoff, anechoic, cameos, lives, boer, overuse, monstrous,
# Nearest to a: shel, pka, planck, ltcm, belloc, boulevard, focused, conceiving,
# Nearest to united: hydroponics, chakra, sinister, insurance, inextricably, kidnap, depressive, soleil,
# Nearest to often: afford, hotel, pedestal, rams, reviews, barnet, uart, megatokyo,
# Nearest to they: solidly, mora, dinosauria, later, chapelle, scavenge, corning, dunant,
# Nearest to one: unison, felt, ferenc, stood, rubin, corning, crystallizes, atahualpa,
# Nearest to he: additionally, looters, mubarak, barbosa, rewriting, writings, willful, yetzer,
# Nearest to no: superstars, rolle, inasmuch, transuranic, seriousness, gojira, ruud, takeoff,
# Nearest to be: unforgettable, spivak, prostaglandin, ezekiel, eyeglasses, remove, arr, stave,
# Nearest to such: carnarvon, pyongyang, counts, happier, rich, specialty, spitz, purify,
# Nearest to most: steadfastly, pohl, turnpike, geostationary, gielgud, corrado, pigpen, reconstruction,
# Nearest to history: divides, petition, appropriate, containers, theologies, tincture, axis, entity,
# Nearest to their: tort, eros, gotham, viewed, cycladic, riddle, premature, soulful,
# Nearest to but: donatello, bloemfontein, voiceover, decolonisation, inductive, eden, maximian, lugs,
# Nearest to nine: hmos, postalveolar, oblast, lighters, szabo, envision, endymion, tba,
# Average loss at step 2000: 4.353458
# Average loss at step 4000: 3.867660
# Average loss at step 6000: 3.782074
# Average loss at step 8000: 3.690021
# Average loss at step 10000: 3.618049
# Nearest to three: eight, five, four, six, seven, two, nine, zero,
# Nearest to if: krahn, kristen, cossacks, anechoic, konkan, committed, via, beheaded,
# Nearest to a: the, boulevard, this, shel, collectively, ingesting, nfs, his,
# Nearest to united: chakra, hydroponics, djing, insurance, soleil, product, verify, fuss,
# Nearest to often: equals, unambiguously, sometimes, not, barnet, conservationist, arius, also,
# Nearest to they: he, not, there, it, mora, later, drenched, byron,
# Nearest to one: two, three, five, seven, six, eight, four, assurance,
# Nearest to he: it, they, she, who, there, chronology, and, authenticity,
# Nearest to no: magnetization, it, vives, polonium, meritocratic, concubine, ethics, rolle,
# Nearest to be: have, is, was, been, are, nixon, by, pervasive,
# Nearest to such: well, beatle, pyongyang, counts, feldman, traditions, persistent, psychoactive,
# Nearest to most: turnpike, pigpen, use, steadfastly, lingered, nueva, geostationary, all,
# Nearest to history: petition, ebbets, divides, aloof, axis, resultant, containers, jumped,
# Nearest to their: his, the, its, riddle, syria, szab, gotham, tort,
# Nearest to but: tuesday, finds, erupting, donatello, she, medication, grudge, tauris,
# Nearest to nine: eight, seven, six, five, three, zero, four, two,
# Average loss at step 12000: 3.606861
# Average loss at step 14000: 3.570593
# Average loss at step 16000: 3.407310
# Average loss at step 18000: 3.464861
# Average loss at step 20000: 3.540145
# Nearest to three: six, seven, four, two, eight, five, zero, nine,
# Nearest to if: when, krahn, cossacks, should, kristen, since, showed, via,
# Nearest to a: shel, this, the, granville, collectively, boulevard, any, gabal,
# Nearest to united: chakra, hydroponics, djing, soleil, insurance, diedrich, renting, diner,
# Nearest to often: sometimes, equals, also, it, barnet, conservationist, generally, unambiguously,
# Nearest to they: he, we, there, it, you, not, who, drenched,
# Nearest to one: two, four, six, three, seven, eight, nine, five,
# Nearest to he: it, she, they, who, there, whorf, which, later,
# Nearest to no: vives, or, medline, any, entre, not, yang, butyl,
# Nearest to be: have, been, is, penfield, become, was, by, are,
# Nearest to such: well, beatle, many, these, feldman, lange, special, glassware,
# Nearest to most: use, pigpen, more, all, many, turnpike, some, nueva,
# Nearest to history: petition, chromic, divides, theories, cliffordadams, computer, tackle, xbox,
# Nearest to their: his, its, the, her, these, some, riichi, many,
# Nearest to but: although, however, which, and, though, that, would, vignettes,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Average loss at step 22000: 3.500046
# Average loss at step 24000: 3.488270
# Average loss at step 26000: 3.486683
# Average loss at step 28000: 3.479520
# Average loss at step 30000: 3.500391
# Nearest to three: five, four, seven, eight, six, two, zero, nine,
# Nearest to if: when, where, minimalist, should, since, but, showed, halpin,
# Nearest to a: any, no, ltcm, jardines, shel, every, suggestibility, deutschen,
# Nearest to united: chakra, djing, hydroponics, insurance, diedrich, soleil, infrastructures, sinister,
# Nearest to often: sometimes, generally, also, there, still, unambiguously, conservationist, usually,
# Nearest to they: we, he, there, you, who, not, it, these,
# Nearest to one: two, four, seven, eight, five, three, six, nine,
# Nearest to he: she, it, they, who, there, whorf, authenticity, tighter,
# Nearest to no: any, vives, still, a, polonium, medline, battista, butyl,
# Nearest to be: been, have, is, become, penfield, pervasive, partnering, was,
# Nearest to such: well, these, known, like, many, feldman, some, romanorum,
# Nearest to most: more, use, pigpen, many, some, apostol, nueva, turnpike,
# Nearest to history: library, theories, huddle, xbox, chromic, aloof, axis, divides,
# Nearest to their: his, its, the, her, these, many, some, riichi,
# Nearest to but: however, although, while, and, that, which, though, he,
# Nearest to nine: eight, seven, six, five, four, three, zero, births,
# Average loss at step 32000: 3.501715
# Average loss at step 34000: 3.488674
# Average loss at step 36000: 3.456981
# Average loss at step 38000: 3.300279
# Average loss at step 40000: 3.431831
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to if: when, where, is, disguises, because, minimalist, governorship, scalp,
# Nearest to a: the, any, another, no, shel, or, granville, innovators,
# Nearest to united: chakra, djing, hydroponics, diedrich, diner, infrastructures, mysia, southern,
# Nearest to often: sometimes, generally, usually, also, still, commonly, there, frequently,
# Nearest to they: we, you, he, there, it, who, she, not,
# Nearest to one: seven, four, eight, two, six, five, three, nine,
# Nearest to he: it, she, they, who, there, later, i, tighter,
# Nearest to no: any, or, a, vives, still, medline, magnetization, malignancies,
# Nearest to be: been, have, were, was, is, become, are, being,
# Nearest to such: well, these, known, saskatoon, superhero, many, beatle, gb,
# Nearest to most: more, many, pigpen, reconstruction, use, apostol, some, togo,
# Nearest to history: sums, ebbets, ecuadorean, tenacity, form, unfit, axis, theories,
# Nearest to their: its, his, her, the, riichi, your, these, some,
# Nearest to but: however, although, while, which, and, though, where, when,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Average loss at step 42000: 3.438282
# Average loss at step 44000: 3.452140
# Average loss at step 46000: 3.452459
# Average loss at step 48000: 3.353163
# Average loss at step 50000: 3.383526
# Nearest to three: six, four, seven, eight, five, nine, two, zero,
# Nearest to if: when, where, before, since, scalp, although, should, disguises,
# Nearest to a: the, another, any, shel, failures, boulevard, no, roden,
# Nearest to united: djing, chakra, hydroponics, infrastructures, syrian, southern, mysia, diedrich,
# Nearest to often: sometimes, generally, usually, commonly, still, frequently, also, now,
# Nearest to they: he, we, there, you, it, she, these, who,
# Nearest to one: two, six, four, eight, three, seven, five, nine,
# Nearest to he: she, it, they, there, who, whorf, nuit, nuova,
# Nearest to no: any, a, sentry, consorts, battista, simulators, magnetization, chieftain,
# Nearest to be: were, been, have, was, is, are, become, partnering,
# Nearest to such: well, these, many, known, superhero, equivocation, saskatoon, intrauterine,
# Nearest to most: more, many, reconstruction, less, use, apostol, pigpen, turnpike,
# Nearest to history: sums, unfit, mems, span, maxima, ecuadorean, tenacity, mosque,
# Nearest to their: its, his, her, the, mysore, our, these, your,
# Nearest to but: however, although, though, while, and, where, when, since,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Average loss at step 52000: 3.433182
# Average loss at step 54000: 3.428478
# Average loss at step 56000: 3.437756
# Average loss at step 58000: 3.394547
# Average loss at step 60000: 3.391157
# Nearest to three: five, four, six, eight, two, seven, nine, zero,
# Nearest to if: when, where, before, though, because, since, should, so,
# Nearest to a: any, the, another, every, innovators, shel, no, ingesting,
# Nearest to united: chakra, djing, hydroponics, syrian, infrastructures, medley, diedrich, mysia,
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, also, now,
# Nearest to they: we, you, there, he, she, these, it, i,
# Nearest to one: four, two, six, eight, seven, five, three, nine,
# Nearest to he: she, it, they, there, whorf, who, nuova, we,
# Nearest to no: any, consorts, a, little, chieftain, kearney, vous, codes,
# Nearest to be: been, have, is, become, were, partnering, erlang, are,
# Nearest to such: well, these, known, many, superhero, including, saskatoon, intrauterine,
# Nearest to most: more, many, some, less, use, reconstruction, pigpen, all,
# Nearest to history: list, politics, ecuadorean, huddle, antagonist, corvettes, movements, rights,
# Nearest to their: its, his, her, the, our, whose, demographic, your,
# Nearest to but: however, although, and, though, which, while, see, when,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Average loss at step 62000: 3.234124
# Average loss at step 64000: 3.254733
# Average loss at step 66000: 3.401987
# Average loss at step 68000: 3.392400
# Average loss at step 70000: 3.354513
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to if: when, though, where, before, since, while, because, should,
# Nearest to a: the, another, any, twinning, shel, every, psalter, amounts,
# Nearest to united: chakra, djing, hydroponics, syrian, infrastructures, following, tamerlane, diner,
# Nearest to often: sometimes, usually, generally, commonly, frequently, also, now, still,
# Nearest to they: we, he, there, you, she, it, actually, these,
# Nearest to one: six, two, seven, four, five, eight, three, nine,
# Nearest to he: she, it, they, who, there, whorf, nuova, we,
# Nearest to no: any, consorts, little, there, beaked, sentry, codes, demeter,
# Nearest to be: been, become, were, is, are, have, being, partnering,
# Nearest to such: well, these, known, superhero, many, equivocation, separate, generalization,
# Nearest to most: more, many, less, reconstruction, some, quartering, lingered, steadfastly,
# Nearest to history: list, biblical, assassination, redesignated, nolan, corvettes, hbk, ecuadorean,
# Nearest to their: its, his, her, the, our, some, your, these,
# Nearest to but: however, although, though, which, that, and, actually, while,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Average loss at step 72000: 3.374199
# Average loss at step 74000: 3.350004
# Average loss at step 76000: 3.312426
# Average loss at step 78000: 3.347111
# Average loss at step 80000: 3.376940
# Nearest to three: four, five, six, seven, two, eight, zero, nine,
# Nearest to if: when, though, before, since, where, because, did, should,
# Nearest to a: the, every, another, roden, operators, deutschen, shel, gabal,
# Nearest to united: chakra, djing, hydroponics, infrastructures, syrian, forbade, athletic, confining,
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, now, rarely,
# Nearest to they: we, he, there, you, she, it, these, actually,
# Nearest to one: seven, six, two, eight, four, three, five, nine,
# Nearest to he: she, it, they, there, who, nuova, we, browed,
# Nearest to no: little, any, sentry, consorts, beaked, codes, bested, mithra,
# Nearest to be: been, become, have, partnering, being, were, refer, nanda,
# Nearest to such: well, these, known, superhero, certain, including, defined, separate,
# Nearest to most: more, many, less, reconstruction, some, among, apostol, especially,
# Nearest to history: list, hbk, emperors, nightmare, corvettes, ecuadorean, tenacity, historical,
# Nearest to their: its, his, her, our, your, the, whose, these,
# Nearest to but: however, although, though, while, and, see, mecha, or,
# Nearest to nine: eight, seven, six, five, four, three, zero, births,
# Average loss at step 82000: 3.410170
# Average loss at step 84000: 3.409590
# Average loss at step 86000: 3.392083
# Average loss at step 88000: 3.350390
# Average loss at step 90000: 3.363069
# Nearest to three: four, five, two, seven, six, eight, nine, zero,
# Nearest to if: when, since, though, before, where, after, refuted, scalp,
# Nearest to a: roden, every, another, woogie, any, the, ltcm, caplan,
# Nearest to united: chakra, djing, following, constitution, hydroponics, infrastructures, syrian, tenth,
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, now, rarely,
# Nearest to they: we, he, there, you, she, it, not, who,
# Nearest to one: seven, four, two, eight, six, five, three, nine,
# Nearest to he: she, it, they, there, who, whorf, browed, later,
# Nearest to no: little, any, specimen, only, sentry, undeniable, characterizing, codes,
# Nearest to be: been, become, have, is, was, refer, being, zubaydah,
# Nearest to such: well, known, these, superhero, certain, many, separate, opposed,
# Nearest to most: more, less, many, some, among, reconstruction, particularly, especially,
# Nearest to history: list, hbk, nightmare, mormon, huddle, ezquerra, krs, corvettes,
# Nearest to their: his, its, her, our, your, the, whose, some,
# Nearest to but: however, although, and, though, while, honecker, he, which,
# Nearest to nine: seven, eight, six, five, four, zero, three, births,
# Average loss at step 92000: 3.398418
# Average loss at step 94000: 3.253503
# Average loss at step 96000: 3.354896
# Average loss at step 98000: 3.242361
# Average loss at step 100000: 3.354259
# Nearest to three: four, five, seven, six, eight, two, nine, zero,
# Nearest to if: when, though, before, since, where, while, so, after,
# Nearest to a: another, any, the, roden, gabal, ltcm, woogie, shel,
# Nearest to united: chakra, djing, infrastructures, following, hydroponics, constitution, tenth, syrian,
# Nearest to often: usually, sometimes, generally, commonly, frequently, rarely, typically, actually,
# Nearest to they: we, he, there, you, she, it, i, not,
# Nearest to one: two, four, six, seven, five, eight, nine, three,
# Nearest to he: she, it, they, there, we, who, never, whorf,
# Nearest to no: any, little, only, codes, advocacy, sentry, there, chill,
# Nearest to be: been, become, have, partnering, refer, erlang, being, is,
# Nearest to such: well, known, these, superhero, separate, certain, many, opposed,
# Nearest to most: more, less, especially, reconstruction, apostol, among, many, particularly,
# Nearest to history: list, hbk, nightmare, span, biblical, ezquerra, moselle, courtenay,
# Nearest to their: its, his, her, our, your, the, these, whose,
# Nearest to but: however, although, and, though, while, when, where, gator,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_cbow_batch(batch_size, num_cbows, cbow_window):
  global data_index
  assert batch_size % num_cbows == 0
  assert num_cbows <= 2 * cbow_window
  # for convinience, batch_size here actually is the size of batch.flatten()
  flat_batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size//num_cbows, 1), dtype=np.int32)
  span = 2 * cbow_window + 1 # [ cbow_window target cbow_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_cbows):
    target = cbow_window  # target label at the center of the buffer
    targets_to_avoid = [ cbow_window ]
    for j in range(num_cbows):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      flat_batch[i * num_cbows + j] = buffer[target]
    labels[i, 0] = buffer[cbow_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    batch = flat_batch.reshape((-1,num_cbows))
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_cbows, cbow_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_cbow_batch(batch_size=8, num_cbows=num_cbows, cbow_window=cbow_window)
    print('\nwith num_cbows = %d and cbow_window = %d:' % (num_cbows, cbow_window))
    
    print('    batch:', [[reverse_dictionary[bij] for bij in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8//num_cbows)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_cbows = 2 and cbow_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['term', 'as'], ['of', 'a']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_cbows = 4 and cbow_window = 2:
#     batch: [['originated', 'term', 'anarchism', 'a'], ['as', 'term', 'of', 'originated']]
#     labels: ['as', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
cbow_window = 2 # How many words to consider left and right.
num_cbows = 4 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  #train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  #train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size//num_cbows,num_cbows])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size//num_cbows, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.reduce_sum(tf.nn.embedding_lookup(embeddings, train_dataset), [1])

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, num_cbows, cbow_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.925443
# Nearest to over: lysander, christiane, serbians, globalization, polarization, kuznetsov, shootings, civilised,
# Nearest to known: tumult, leans, eia, breeder, josephus, unifil, rita, plaster,
# Nearest to may: seduce, lurking, acapulco, marijuana, therefore, amazing, durban, hohmann,
# Nearest to after: emissary, davids, brummell, milder, aggressors, besieging, marr, recipients,
# Nearest to at: granules, elohim, frida, cockburn, aggregate, ladders, fide, scum,
# Nearest to more: giacomo, fried, projective, frs, regional, mccann, favourites, scot,
# Nearest to only: strasberg, leroy, microsoft, orfeo, chipsets, removing, baur, lives,
# Nearest to from: holliday, instituted, irl, uplink, upholding, psilocybin, shura, tricking,
# Nearest to four: minimalism, endian, majuro, hosted, sage, sheltered, coherent, wrongdoing,
# Nearest to b: phil, dafoe, harpercollins, catania, pan, concessions, vanilla, cmd,
# Nearest to will: inauguration, explained, accomplice, corporal, fable, encoder, cynic, fluorine,
# Nearest to seven: sustains, psychotherapist, carriers, sphincter, algardi, plaintiff, slew, gent,
# Nearest to one: tien, damping, grampus, outbound, sampa, titular, pacemakers, antecedent,
# Nearest to UNK: eliminates, punic, diversions, pepys, engined, origins, continues, ovulation,
# Nearest to on: rifled, noaa, milwaukee, le, officiated, captive, shores, durian,
# Nearest to into: yarmouth, ambrose, um, coens, excerpted, lactation, fujitsu, cours,
# Average loss at step 2000: 6.185424
# Average loss at step 4000: 5.319203
# Average loss at step 6000: 5.151704
# Average loss at step 8000: 5.074501
# Average loss at step 10000: 4.899031
# Nearest to over: latour, wmd, ecologically, girl, isadora, ratzinger, decide, unravel,
# Nearest to known: clyde, referred, inauguration, adm, systems, used, awarding, misspelled,
# Nearest to may: could, can, should, will, cannot, would, iho, appears,
# Nearest to after: earthworm, formally, at, mt, erebus, ii, dinosaur, heteronyms,
# Nearest to at: overwhelmingly, on, after, europeans, volcano, ross, dolphin, importing,
# Nearest to more: kal, less, hacking, jewry, engagement, sixties, gravy, wolfman,
# Nearest to only: mt, active, formally, angola, aircraft, declared, dung, island,
# Nearest to from: frieze, between, bara, within, arguable, quicktime, laches, kale,
# Nearest to four: ovaries, nine, classified, amethyst, seven, landslide, inconceivable, coolidge,
# Nearest to b: mafia, geometries, lillehammer, rate, outputting, breda, brooke, mashal,
# Nearest to will: could, can, may, did, to, cannot, might, inspires,
# Nearest to seven: nine, eight, four, surgeries, bowie, shipments, percentile, caustic,
# Nearest to one: talib, cartier, circumstantial, bitterness, akc, zero, quantification, ripper,
# Nearest to UNK: gulf, dusseldorf, witten, rakis, plundering, armature, persecutions, bear,
# Nearest to on: island, erebus, ross, sweep, active, market, dolphin, donkey,
# Nearest to into: reviewer, opener, costume, horribilis, ursula, brings, cozy, buckland,
# Average loss at step 12000: 4.694953
# Average loss at step 14000: 4.582830
# Average loss at step 16000: 4.314434
# Average loss at step 18000: 4.392874
# Average loss at step 20000: 4.263382
# Nearest to over: upbringing, intrigued, bombs, cocoa, cravings, circumcised, kouchner, cigars,
# Nearest to known: chap, described, such, doing, judeo, juice, abominable, ghb,
# Nearest to may: would, should, can, to, must, might, could, cannot,
# Nearest to after: before, medals, sennett, pronouncing, ux, behind, francophone, lithuanian,
# Nearest to at: speller, schistosomiasis, equalizer, revolutionize, anubis, sto, sortavala, castle,
# Nearest to more: typically, iers, less, rather, eps, solute, aground, openstep,
# Nearest to only: past, innes, ascorbic, selectively, professions, invalid, unsettled, bacchus,
# Nearest to from: mikoyan, dishonesty, plectrum, in, on, outfielder, alfv, breve,
# Nearest to four: gave, six, seven, nine, three, two, landau, brigade,
# Nearest to b: d, popularizing, dermal, drawings, core, politician, teborg, woke,
# Nearest to will: could, would, should, testimonium, can, did, must, may,
# Nearest to seven: three, four, nine, stumbling, two, zero, six, five,
# Nearest to one: trivium, proton, mph, schneider, particle, humour, cantilever, envision,
# Nearest to UNK: ath, fethry, hani, olson, clipperton, malays, cosmonauts, hooked,
# Nearest to on: within, in, votive, latveria, ned, for, armory, bol,
# Nearest to into: to, coeducational, leche, eggs, generalizes, making, garden, unproductive,
# Average loss at step 22000: 4.123037
# Average loss at step 24000: 4.227012
# Average loss at step 26000: 3.958049
# Average loss at step 28000: 3.836250
# Average loss at step 30000: 3.799360
# Nearest to over: mclaughlin, hbar, rooney, nr, bronchitis, viterbo, vied, frontiersman,
# Nearest to known: referred, described, used, ferraris, regarded, mellor, famous, far,
# Nearest to may: can, should, must, would, could, might, will, to,
# Nearest to after: mississippian, daimyo, marjoram, for, before, sukhum, fairey, afterwards,
# Nearest to at: in, eridanus, emergent, roasting, thaddeus, mizrahi, for, during,
# Nearest to more: less, most, very, openstep, basins, ignores, pectoral, dose,
# Nearest to only: shaking, bishoprics, legalisation, aged, block, cavitation, castiglione, petra,
# Nearest to from: in, garibaldi, ale, ebbinghaus, towards, of, into, chancellors,
# Nearest to four: three, six, eight, zero, amorites, two, auk, five,
# Nearest to b: d, rockefeller, kar, tears, distinctions, popularize, vecchio, melancholy,
# Nearest to will: should, could, can, shall, may, must, would, constantin,
# Nearest to seven: five, eight, three, zero, nine, larch, tap, neutrinos,
# Nearest to one: riigikogu, millions, abeyance, saviola, schemas, ardal, protruding, zawahiri,
# Nearest to UNK: manley, lifeforms, leben, processes, loom, lossless, excess, landesverband,
# Nearest to on: in, bikes, during, hadn, bachelet, transcontinental, unintentional, from,
# Nearest to into: minced, hazael, from, legalisation, cylindrical, comanche, bucky, across,
# Average loss at step 32000: 3.813046
# Average loss at step 34000: 3.995079
# Average loss at step 36000: 3.865535
# Average loss at step 38000: 3.890003
# Average loss at step 40000: 3.851431
# Nearest to over: sacra, bosman, tether, mestre, manzarek, legume, from, glasnost,
# Nearest to known: recognized, described, referred, used, dyed, devour, abominable, identified,
# Nearest to may: will, might, must, can, should, would, could, cannot,
# Nearest to after: before, samarkand, so, of, medals, phylum, iib, aoc,
# Nearest to at: on, freedoms, under, when, in, platt, ratsiraka, defraud,
# Nearest to more: less, most, better, rather, greater, areal, allis, bodmin,
# Nearest to only: antibacterial, stabilizes, teal, yahweh, corps, universidad, wildstorm, thriving,
# Nearest to from: of, with, into, under, in, by, mikoyan, dekker,
# Nearest to four: two, lieberman, three, finalized, impeccable, gaiman, mizrahi, indomitable,
# Nearest to b: inflammatory, urn, upholds, criollo, islington, anasazi, aisle, birthright,
# Nearest to will: can, may, must, would, could, should, cannot, might,
# Nearest to seven: five, nine, yassin, edith, aediles, six, cursus, zero,
# Nearest to one: sacrament, cdots, vicious, garand, seven, booch, faroese, felons,
# Nearest to UNK: flogging, santiago, methylation, decolonization, roslin, tai, coaster, clowning,
# Nearest to on: at, in, into, since, aeolian, although, bock, through,
# Nearest to into: in, through, on, from, coniferous, holbein, rebates, inapplicable,
# Average loss at step 42000: 3.770257
# Average loss at step 44000: 3.793840
# Average loss at step 46000: 3.675022
# Average loss at step 48000: 3.820206
# Average loss at step 50000: 3.626803
# Nearest to over: against, before, after, at, under, improperly, spent, for,
# Nearest to known: referred, used, seen, regarded, viewed, understood, believed, released,
# Nearest to may: can, should, could, must, would, cannot, might, did,
# Nearest to after: at, in, medals, of, before, over, despite, for,
# Nearest to at: after, over, in, einer, ronstadt, speller, flowery, mikoyan,
# Nearest to more: less, rather, conscription, most, felons, lcds, openstep, breakdancing,
# Nearest to only: pwn, diaries, plekhanov, janet, fixtures, karnataka, kelvin, always,
# Nearest to from: dekker, upon, fundamento, toward, watcher, into, in, leste,
# Nearest to four: three, zero, seven, six, five, eight, gauguin, nine,
# Nearest to b: d, sgml, anasazi, scholarships, bot, bylaws, tir, taland,
# Nearest to will: would, could, must, can, might, should, may, cannot,
# Nearest to seven: six, eight, nine, four, five, hammurabi, calamities, anmen,
# Nearest to one: abeyance, readability, eight, kludge, reproducible, upanishads, dnia, goods,
# Nearest to UNK: ben, berenson, toulouse, serre, keynesians, missed, bassoons, encha,
# Nearest to on: upon, in, throughout, mallets, monica, cozy, interrogation, islami,
# Nearest to into: from, peanut, veneer, lamp, clouded, to, battista, kondratiev,
# Average loss at step 52000: 3.665195
# Average loss at step 54000: 3.803944
# Average loss at step 56000: 3.754416
# Average loss at step 58000: 3.597679
# Average loss at step 60000: 3.684957
# Nearest to over: during, at, through, throughout, camden, estado, unitarian, tuscan,
# Nearest to known: referred, regarded, used, described, identified, considered, served, depicted,
# Nearest to may: can, might, would, should, must, could, will, cannot,
# Nearest to after: before, wis, hoses, metis, buell, nearly, finals, impetuous,
# Nearest to at: in, over, alligators, pinocchio, for, vaikundar, riddler, brindisi,
# Nearest to more: less, rather, better, greater, how, most, stances, ferro,
# Nearest to only: who, bordeaux, always, austere, iona, aphids, i, polluted,
# Nearest to from: into, in, giving, on, mikoyan, patenting, through, with,
# Nearest to four: five, advocating, six, dada, falsified, hedgehog, toss, eight,
# Nearest to b: lysergic, isuzu, ab, uranhay, p, virtuous, alkoxide, singh,
# Nearest to will: could, can, may, must, would, might, should, vitry,
# Nearest to seven: nine, eight, harrier, five, x, vald, dogmas, everyman,
# Nearest to one: completions, cuon, dnia, connelly, superscalar, tyrannical, two, pedantic,
# Nearest to UNK: und, widowers, pollutants, angiosperms, hermitage, sacks, inwards, abalone,
# Nearest to on: above, from, upon, in, by, amherst, tubas, pryor,
# Nearest to into: from, in, drab, primigenius, by, like, vacations, fangio,
# Average loss at step 62000: 3.691642
# Average loss at step 64000: 3.723353
# Average loss at step 66000: 3.321085
# Average loss at step 68000: 3.303415
# Average loss at step 70000: 3.627278
# Nearest to over: on, throughout, of, through, advisory, ten, during, together,
# Nearest to known: regarded, served, referred, classified, recognized, described, considered, portrayed,
# Nearest to may: might, can, could, should, will, would, must, cannot,
# Nearest to after: pv, gbase, prelog, before, electrolyte, during, discharged, hibbert,
# Nearest to at: during, associates, sedan, in, slipper, scrupulously, on, stadler,
# Nearest to more: less, rather, greater, higher, most, very, larger, openstep,
# Nearest to only: bottlenose, laine, ample, deletions, joliot, resides, glaciations, calicut,
# Nearest to from: in, into, across, between, until, mikoyan, on, within,
# Nearest to four: three, five, six, eight, seven, zero, kashubian, pellets,
# Nearest to b: programmable, constellations, letterboxes, marathas, subhas, tumour, tarkovsky, manipulating,
# Nearest to will: would, can, must, could, may, might, should, cannot,
# Nearest to seven: three, eight, uttered, four, nine, six, five, zero,
# Nearest to one: unrequited, canned, accordance, everly, algeria, cochrane, christiern, wines,
# Nearest to UNK: befell, harlequin, cerrado, beep, tiled, www, gibbs, vagus,
# Nearest to on: upon, in, since, over, through, of, for, from,
# Nearest to into: from, cryonicists, by, when, ges, knit, quicksort, railhead,
# Average loss at step 72000: 3.471719
# Average loss at step 74000: 3.641736
# Average loss at step 76000: 3.430173
# Average loss at step 78000: 3.619408
# Average loss at step 80000: 3.473169
# Nearest to over: pew, baserunner, blaze, throughout, mainframe, beyond, during, lodger,
# Nearest to known: regarded, referred, served, classified, described, used, recognized, possible,
# Nearest to may: can, must, might, would, should, cannot, could, does,
# Nearest to after: before, during, for, actinidia, olivier, and, in, mackaye,
# Nearest to at: where, vauban, in, from, wands, testosterone, speller, during,
# Nearest to more: less, stronger, rather, greater, better, increasingly, quick, fewer,
# Nearest to only: practically, diaries, regimens, ziegfeld, hoffer, sedation, tapping, magnates,
# Nearest to from: and, into, with, in, on, across, including, baxter,
# Nearest to four: three, five, six, seven, eight, vantage, nine, celsius,
# Nearest to b: gen, zawahiri, sidebands, clarke, hasse, traits, figure, gilliam,
# Nearest to will: would, can, must, should, did, cannot, shall, might,
# Nearest to seven: zero, three, eight, nine, five, four, six, sixteen,
# Nearest to one: driftwood, signified, contrast, expos, romanticized, pvt, steyr, hydrochloric,
# Nearest to UNK: h, plum, edsac, cad, di, o, ez, hypotension,
# Nearest to on: upon, in, beyond, across, overloading, from, retrieved, savoury,
# Nearest to into: from, in, during, handedly, across, xt, baserunners, endoplasmic,
# Average loss at step 82000: 3.585143
# Average loss at step 84000: 3.442535
# Average loss at step 86000: 3.457834
# Average loss at step 88000: 3.394592
# Average loss at step 90000: 3.325552
# Nearest to over: cic, impulses, ferrara, under, on, jaime, connolly, capp,
# Nearest to known: regarded, referred, used, described, portrayed, defined, served, classified,
# Nearest to may: would, can, could, might, must, cannot, will, should,
# Nearest to after: during, following, if, before, deir, on, of, and,
# Nearest to at: of, during, maui, precipitating, around, reached, lest, with,
# Nearest to more: less, rather, most, stronger, better, quick, fewer, felons,
# Nearest to only: angular, cuny, unsuitable, aircraft, wp, minimal, chueca, awry,
# Nearest to from: into, in, on, against, and, towards, through, leste,
# Nearest to four: three, five, eight, seven, lovers, zero, nuanced, lingo,
# Nearest to b: carbine, diego, di, barbarossa, gosling, k, barbaric, grandchildren,
# Nearest to will: could, would, should, might, can, must, may, cannot,
# Nearest to seven: six, eight, nine, four, three, luxembourgish, eq, aediles,
# Nearest to one: heijenoort, jotham, quadrilateral, alphabets, whitby, francis, thirties, gamma,
# Nearest to UNK: smith, nigerian, nelson, richardson, crouching, tom, impresario, anz,
# Nearest to on: upon, into, from, in, through, latveria, minster, across,
# Nearest to into: from, on, towards, in, across, ergative, skylark, beyond,
# Average loss at step 92000: 3.480624
# Average loss at step 94000: 3.488695
# Average loss at step 96000: 3.394813
# Average loss at step 98000: 3.491190
# Average loss at step 100000: 3.447110
# Nearest to over: renounced, ciboney, marquesas, motivate, off, during, abruptly, petrovich,
# Nearest to known: referred, described, regarded, used, defined, seen, called, identified,
# Nearest to may: can, might, should, would, could, must, will, cannot,
# Nearest to after: before, at, during, for, iib, afterwards, following, until,
# Nearest to at: after, in, speller, during, on, before, by, until,
# Nearest to more: less, faster, better, larger, rather, smaller, very, fewer,
# Nearest to only: adrift, heterochromatin, maududi, extraordinarily, four, officially, amu, coli,
# Nearest to from: into, in, through, of, and, back, until, reinventing,
# Nearest to four: five, six, two, three, zero, pellets, seven, zahn,
# Nearest to b: inverting, necropolis, uranium, barbarossa, waid, clock, healer, oldfield,
# Nearest to will: would, can, could, must, should, did, might, cannot,
# Nearest to seven: eight, nine, five, zero, six, four, th, bedfordshire,
# Nearest to one: foresight, subtitle, clamp, cth, seasons, stormed, somerset, foodcrops,
# Nearest to UNK: el, wilhelm, haggard, neocortex, retrieved, puget, crustaceans, hillel,
# Nearest to on: upon, minster, in, at, retrieved, concerning, vox, until,
# Nearest to into: from, through, inside, in, until, cryonicists, within, pwnage,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
