# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
a = dict()
print(a)
# Out:
# {}

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])

del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.882977
# Nearest to are: methodus, covalent, palgrave, superstitions, turnaround, spokane, sinuous, hostage,
# Nearest to s: direct, sieur, nieve, disproportionate, contributing, yokoi, manhood, events,
# Nearest to a: prophesies, guillotined, peleus, carmack, flamboyant, establishment, variants, tasking,
# Nearest to these: koh, kuril, rosenzweig, chthonic, unclean, port, rebelled, recognising,
# Nearest to many: brahmaputra, treviso, pershing, ambients, rhyolite, affiliate, tong, lafur,
# Nearest to up: craig, hobbyist, godlike, khattab, elven, pkn, complementary, pashtuns,
# Nearest to b: sections, frenchman, ball, jiao, carolingian, monarch, pots, localities,
# Nearest to when: allahabad, hennecke, encke, gush, too, plugged, cfcs, expansionism,
# Nearest to eight: commanded, interviewer, regulating, elective, boopsie, ffffff, transfinite, banco,
# Nearest to only: rta, ncipe, spp, acadia, jaian, glucocorticoids, lapse, reloaded,
# Nearest to of: endnotes, mirza, ifbb, dictated, easterly, macross, correlations, agencies,
# Nearest to there: attempts, leo, aniston, decolonization, nav, keralite, vojvodina, green,
# Nearest to known: slit, normal, applications, qassam, requirements, acquainted, positively, tamper,
# Nearest to state: geri, cdi, removed, adin, ejection, injuries, lemnos, schliemann,
# Nearest to had: increases, rnzaf, kuleshov, quirky, diogo, penguins, distinctions, walker,
# Nearest to who: amyotrophic, unwelcome, seine, stages, compel, taming, fijians, bunge,
# Average loss at step 2000: 4.356027
# Average loss at step 4000: 3.860231
# Average loss at step 6000: 3.789939
# Average loss at step 8000: 3.686191
# Average loss at step 10000: 3.610806
# Nearest to are: were, is, have, password, was, smit, be, confusion,
# Nearest to s: his, discontented, hermetic, ie, analyse, cordial, cjd, the,
# Nearest to a: the, this, haldeman, avalanche, archive, thermals, baggins, prophesies,
# Nearest to these: chthonic, oireachtas, some, fetish, many, systems, blackadder, por,
# Nearest to many: some, nestorianism, brahmaputra, these, rhyolite, sebald, aire, loathing,
# Nearest to up: hobbyist, godlike, craig, khattab, belief, tiberius, pkn, elven,
# Nearest to b: d, dunant, space, athena, ball, therefore, rounders, federer,
# Nearest to when: schemata, plugged, gush, pavement, lusaka, counterfeit, encke, hennecke,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to only: rta, lapse, seperate, reloaded, bite, eec, flanagan, meridian,
# Nearest to of: in, at, united, adjoined, from, nobody, for, hissarlik,
# Nearest to there: it, attempts, bogs, they, decolonization, scientists, leo, thermodynamically,
# Nearest to known: such, tamper, normal, acquainted, slit, requirements, qassam, well,
# Nearest to state: ejection, cdi, removed, injuries, geri, eigenstates, obituary, samarium,
# Nearest to had: has, have, was, publically, transshipment, exemplary, sfsr, increases,
# Nearest to who: he, which, benito, chakras, clancy, jsf, seine, amyotrophic,
# Average loss at step 12000: 3.601362
# Average loss at step 14000: 3.569568
# Average loss at step 16000: 3.405738
# Average loss at step 18000: 3.457093
# Average loss at step 20000: 3.534269
# Nearest to are: were, is, have, was, disqualified, password, affix, alkalis,
# Nearest to s: parlour, hermetic, disproven, venezuelan, geologically, fingerings, sperm, fv,
# Nearest to a: another, haldeman, avalanche, archive, satirize, this, biker, disowned,
# Nearest to these: some, many, systems, all, such, fetish, oireachtas, starved,
# Nearest to many: some, these, several, other, all, most, systems, driving,
# Nearest to up: godlike, belief, pkn, nephew, hobbyist, tiberius, patti, asymptotically,
# Nearest to b: d, german, dunant, athena, rounders, derrida, director, catalyse,
# Nearest to when: basutoland, counterfeit, showdown, if, behaves, was, pavement, cherished,
# Nearest to eight: seven, six, nine, four, five, three, zero, two,
# Nearest to only: meridian, reloaded, rta, belichick, mistake, bite, nikolaus, do,
# Nearest to of: for, rites, lately, stoneman, putin, haven, pdi, awoke,
# Nearest to there: it, they, he, which, imi, bogs, diameters, who,
# Nearest to known: such, used, well, tamper, acquainted, unfettered, considered, benguela,
# Nearest to state: cdi, geri, eigenstates, injuries, samarium, ejection, pittsburg, obituary,
# Nearest to had: has, have, was, were, having, transshipment, gave, correcting,
# Nearest to who: he, which, they, chakras, also, benito, julie, claire,
# Average loss at step 22000: 3.511042
# Average loss at step 24000: 3.489625
# Average loss at step 26000: 3.479166
# Average loss at step 28000: 3.479851
# Average loss at step 30000: 3.500043
# Nearest to are: were, is, have, be, password, other, include, evidently,
# Nearest to s: his, disproven, her, lanes, and, keyword, mem, hermetic,
# Nearest to a: archive, controls, any, no, the, nucleotides, dockyard, shank,
# Nearest to these: some, many, such, all, they, their, both, other,
# Nearest to many: some, several, these, other, their, various, most, different,
# Nearest to up: them, godlike, him, tiberius, pkn, belief, nephew, asymptotically,
# Nearest to b: d, rounders, therefore, catalyse, athena, neuro, jiao, doctrinal,
# Nearest to when: if, before, until, basutoland, during, while, after, where,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to only: belichick, seperate, nikolaus, eddic, bite, auric, reloaded, mistake,
# Nearest to of: in, devon, for, from, carcasses, haven, stoneman, schwartz,
# Nearest to there: they, it, he, still, this, thermodynamically, now, often,
# Nearest to known: used, such, unfettered, well, considered, benguela, tamper, described,
# Nearest to state: cdi, ejection, injuries, partitions, schliemann, geri, bicycles, city,
# Nearest to had: has, have, was, were, having, is, give, began,
# Nearest to who: he, they, which, also, she, chakras, there, benito,
# Average loss at step 32000: 3.500308
# Average loss at step 34000: 3.494748
# Average loss at step 36000: 3.451541
# Average loss at step 38000: 3.302281
# Average loss at step 40000: 3.418795
# Nearest to are: were, is, have, be, but, was, internationals, those,
# Nearest to s: his, duplicated, unprofitable, lekhanya, cubans, cautious, chromatin, her,
# Nearest to a: the, thermals, haldeman, kampaku, satirize, hatred, another, dkk,
# Nearest to these: many, some, such, both, different, various, they, several,
# Nearest to many: some, several, these, various, most, different, other, zfc,
# Nearest to up: them, out, godlike, him, pkn, back, tiberius, off,
# Nearest to b: d, c, r, f, vlsi, neuro, UNK, therefore,
# Nearest to when: if, while, where, before, was, congressional, during, after,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to only: scientists, no, belichick, retells, bite, eddic, consult, brew,
# Nearest to of: in, from, for, haven, tradeoff, original, porpoise, chemical,
# Nearest to there: they, it, he, still, now, thermodynamically, she, often,
# Nearest to known: such, used, unfettered, considered, well, benguela, acquainted, lin,
# Nearest to state: cdi, partitions, injuries, larval, eigenstates, ejection, schliemann, bicycles,
# Nearest to had: has, have, was, were, began, having, since, posner,
# Nearest to who: which, he, also, they, often, she, but, chakras,
# Average loss at step 42000: 3.440571
# Average loss at step 44000: 3.453455
# Average loss at step 46000: 3.452778
# Average loss at step 48000: 3.350437
# Average loss at step 50000: 3.383558
# Nearest to are: were, is, have, evidently, these, those, be, disqualified,
# Nearest to s: whose, his, starters, parlour, jinshi, medgar, vos, rajah,
# Nearest to a: another, hardliners, any, the, approximated, provisioning, histones, castilla,
# Nearest to these: some, many, both, various, such, several, those, their,
# Nearest to many: some, several, these, various, other, most, those, such,
# Nearest to up: out, them, him, off, pkn, back, tiberius, godlike,
# Nearest to b: d, r, f, c, h, vlsi, p, five,
# Nearest to when: if, while, where, after, before, during, until, although,
# Nearest to eight: six, seven, four, nine, five, three, zero, two,
# Nearest to only: principal, first, withstood, mortals, filipinos, huac, founds, outcasts,
# Nearest to of: in, invert, devon, aron, tradeoff, edi, intruder, and,
# Nearest to there: they, it, he, she, still, now, who, thermodynamically,
# Nearest to known: used, such, unfettered, considered, well, regarded, described, benguela,
# Nearest to state: cdi, partitions, hospital, avenger, kingdom, eigenstates, states, varieties,
# Nearest to had: has, have, was, having, were, began, been, since,
# Nearest to who: which, he, there, also, she, chakras, they, benito,
# Average loss at step 52000: 3.438998
# Average loss at step 54000: 3.425678
# Average loss at step 56000: 3.439096
# Average loss at step 58000: 3.400949
# Average loss at step 60000: 3.396741
# Nearest to are: were, is, have, evidently, be, include, those, including,
# Nearest to s: whose, cjd, awesome, deformities, although, starters, notepad, cubans,
# Nearest to a: another, the, any, latium, dkk, apa, curie, avalanche,
# Nearest to these: some, many, both, those, several, various, such, different,
# Nearest to many: some, several, these, various, most, other, such, all,
# Nearest to up: out, off, him, them, back, pkn, down, exquisite,
# Nearest to b: d, c, r, f, h, vlsi, p, dias,
# Nearest to when: if, before, while, after, during, although, where, because,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Nearest to only: first, principal, consult, founds, historically, filipinos, transnistrian, easily,
# Nearest to of: for, in, tradeoff, psych, devon, pdi, cognition, offshoots,
# Nearest to there: they, it, he, now, still, she, this, often,
# Nearest to known: used, such, considered, regarded, described, well, unfettered, benguela,
# Nearest to state: cdi, states, kingdom, government, hospital, entanglement, partitions, avenger,
# Nearest to had: has, have, was, having, correcting, were, became, been,
# Nearest to who: he, still, which, chakras, also, now, julie, actually,
# Average loss at step 62000: 3.235330
# Average loss at step 64000: 3.257311
# Average loss at step 66000: 3.404271
# Average loss at step 68000: 3.397853
# Average loss at step 70000: 3.355927
# Nearest to are: were, have, is, include, these, although, including, those,
# Nearest to s: whose, isbn, tonkin, teller, fingerings, awesome, his, shafts,
# Nearest to a: the, another, dockyard, eui, haldeman, rinks, satirize, any,
# Nearest to these: many, such, some, those, several, various, are, the,
# Nearest to many: some, several, these, various, most, all, such, other,
# Nearest to up: off, out, them, back, him, down, pkn, exquisite,
# Nearest to b: d, r, f, h, c, p, honeywell, dias,
# Nearest to when: if, before, while, where, because, though, after, although,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to only: easily, necessarily, nikolaus, consult, raised, not, spinal, unsympathetic,
# Nearest to of: including, and, include, original, in, for, avc, although,
# Nearest to there: they, it, still, he, she, we, now, typically,
# Nearest to known: used, regarded, such, considered, described, unfettered, well, benguela,
# Nearest to state: states, government, entanglement, avenger, kingdom, pittsburg, laban, ing,
# Nearest to had: has, have, was, were, having, correcting, been, began,
# Nearest to who: he, chakras, still, she, now, which, doppelbock, umar,
# Average loss at step 72000: 3.374516
# Average loss at step 74000: 3.348922
# Average loss at step 76000: 3.316845
# Average loss at step 78000: 3.349534
# Average loss at step 80000: 3.380413
# Nearest to are: were, have, include, is, including, these, be, although,
# Nearest to s: synergy, parlour, whose, tonkin, witten, grazing, arnhem, encodes,
# Nearest to a: the, pumped, any, kordofanian, another, spacey, ergo, offensively,
# Nearest to these: several, various, those, many, both, such, some, none,
# Nearest to many: several, some, various, these, most, multiple, all, numerous,
# Nearest to up: off, out, them, down, back, pkn, him, exquisite,
# Nearest to b: d, r, c, h, p, lambda, dias, f,
# Nearest to when: before, if, after, during, while, though, because, although,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to only: plural, first, easily, consult, silently, last, sympathy, cranial,
# Nearest to of: regicide, tradeoff, in, pdi, easterly, including, original, eudoxus,
# Nearest to there: it, they, he, she, still, usually, we, often,
# Nearest to known: used, regarded, described, considered, such, unfettered, defined, called,
# Nearest to state: states, government, college, quorum, city, subtlety, entanglement, avenger,
# Nearest to had: has, have, was, were, having, began, became, been,
# Nearest to who: he, she, actually, chakras, they, which, never, damien,
# Average loss at step 82000: 3.406487
# Average loss at step 84000: 3.407328
# Average loss at step 86000: 3.390709
# Average loss at step 88000: 3.347349
# Average loss at step 90000: 3.361008
# Nearest to are: were, is, have, include, these, contain, although, containing,
# Nearest to s: whose, quirks, his, isbn, teller, wheatstone, arnhem, starters,
# Nearest to a: the, another, differently, nucleotides, any, hardliners, kordofanian, comstock,
# Nearest to these: several, some, many, various, those, such, all, instead,
# Nearest to many: several, some, these, various, all, numerous, most, multiple,
# Nearest to up: off, out, down, back, them, him, pkn, together,
# Nearest to b: d, r, h, f, c, k, p, honeywell,
# Nearest to when: before, if, while, after, where, because, during, though,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to only: passes, no, principal, inherently, embraced, therefore, skip, actually,
# Nearest to of: including, tradeoff, in, for, amelia, from, pdi, devon,
# Nearest to there: they, it, he, still, she, we, now, often,
# Nearest to known: used, regarded, such, described, unfettered, considered, called, referred,
# Nearest to state: government, states, city, college, entanglement, translators, transatlantic, subtlety,
# Nearest to had: has, have, was, were, having, exaggeration, been, since,
# Nearest to who: he, which, she, also, they, often, still, but,
# Average loss at step 92000: 3.396623
# Average loss at step 94000: 3.253114
# Average loss at step 96000: 3.359931
# Average loss at step 98000: 3.242374
# Average loss at step 100000: 3.357014
# Nearest to are: were, have, include, those, these, while, be, croft,
# Nearest to s: whose, his, automator, her, teller, venezuelan, your, definitional,
# Nearest to a: another, the, any, approximated, latium, dunlop, ornamented, pumped,
# Nearest to these: several, some, many, those, various, all, multiple, their,
# Nearest to many: several, some, these, various, numerous, all, few, multiple,
# Nearest to up: off, out, back, him, down, them, pkn, tiberius,
# Nearest to b: d, c, distal, mercer, lambda, therefore, r, transboundary,
# Nearest to when: if, before, while, because, although, after, though, where,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to only: within, still, never, no, passes, embraced, principal, therefore,
# Nearest to of: including, original, in, although, precedes, fungal, regicide, and,
# Nearest to there: they, it, we, he, still, now, she, often,
# Nearest to known: such, regarded, used, described, unfettered, considered, defined, called,
# Nearest to state: states, laban, college, subtlety, government, justice, entanglement, carolina,
# Nearest to had: has, have, was, having, were, is, since, would,
# Nearest to who: he, she, actually, never, which, also, now, still,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
