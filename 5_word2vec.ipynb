# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
a = dict()
print(a)
# Out:
# {}

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])

del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3081, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.178864
# Nearest to three: blues, monies, powiat, climber, besieged, fortunate, feasibility, reconstructionist,
# Nearest to if: konkan, kickoff, anechoic, cameos, lives, boer, overuse, monstrous,
# Nearest to a: shel, pka, planck, ltcm, belloc, boulevard, focused, conceiving,
# Nearest to united: hydroponics, chakra, sinister, insurance, inextricably, kidnap, depressive, soleil,
# Nearest to often: afford, hotel, pedestal, rams, reviews, barnet, uart, megatokyo,
# Nearest to they: solidly, mora, dinosauria, later, chapelle, scavenge, corning, dunant,
# Nearest to one: unison, felt, ferenc, stood, rubin, corning, crystallizes, atahualpa,
# Nearest to he: additionally, looters, mubarak, barbosa, rewriting, writings, willful, yetzer,
# Nearest to no: superstars, rolle, inasmuch, transuranic, seriousness, gojira, ruud, takeoff,
# Nearest to be: unforgettable, spivak, prostaglandin, ezekiel, eyeglasses, remove, arr, stave,
# Nearest to such: carnarvon, pyongyang, counts, happier, rich, specialty, spitz, purify,
# Nearest to most: steadfastly, pohl, turnpike, geostationary, gielgud, corrado, pigpen, reconstruction,
# Nearest to history: divides, petition, appropriate, containers, theologies, tincture, axis, entity,
# Nearest to their: tort, eros, gotham, viewed, cycladic, riddle, premature, soulful,
# Nearest to but: donatello, bloemfontein, voiceover, decolonisation, inductive, eden, maximian, lugs,
# Nearest to nine: hmos, postalveolar, oblast, lighters, szabo, envision, endymion, tba,
# Average loss at step 2000: 4.353458
# Average loss at step 4000: 3.867660
# Average loss at step 6000: 3.782074
# Average loss at step 8000: 3.690021
# Average loss at step 10000: 3.618049
# Nearest to three: eight, five, four, six, seven, two, nine, zero,
# Nearest to if: krahn, kristen, cossacks, anechoic, konkan, committed, via, beheaded,
# Nearest to a: the, boulevard, this, shel, collectively, ingesting, nfs, his,
# Nearest to united: chakra, hydroponics, djing, insurance, soleil, product, verify, fuss,
# Nearest to often: equals, unambiguously, sometimes, not, barnet, conservationist, arius, also,
# Nearest to they: he, not, there, it, mora, later, drenched, byron,
# Nearest to one: two, three, five, seven, six, eight, four, assurance,
# Nearest to he: it, they, she, who, there, chronology, and, authenticity,
# Nearest to no: magnetization, it, vives, polonium, meritocratic, concubine, ethics, rolle,
# Nearest to be: have, is, was, been, are, nixon, by, pervasive,
# Nearest to such: well, beatle, pyongyang, counts, feldman, traditions, persistent, psychoactive,
# Nearest to most: turnpike, pigpen, use, steadfastly, lingered, nueva, geostationary, all,
# Nearest to history: petition, ebbets, divides, aloof, axis, resultant, containers, jumped,
# Nearest to their: his, the, its, riddle, syria, szab, gotham, tort,
# Nearest to but: tuesday, finds, erupting, donatello, she, medication, grudge, tauris,
# Nearest to nine: eight, seven, six, five, three, zero, four, two,
# Average loss at step 12000: 3.606861
# Average loss at step 14000: 3.570593
# Average loss at step 16000: 3.407310
# Average loss at step 18000: 3.464861
# Average loss at step 20000: 3.540145
# Nearest to three: six, seven, four, two, eight, five, zero, nine,
# Nearest to if: when, krahn, cossacks, should, kristen, since, showed, via,
# Nearest to a: shel, this, the, granville, collectively, boulevard, any, gabal,
# Nearest to united: chakra, hydroponics, djing, soleil, insurance, diedrich, renting, diner,
# Nearest to often: sometimes, equals, also, it, barnet, conservationist, generally, unambiguously,
# Nearest to they: he, we, there, it, you, not, who, drenched,
# Nearest to one: two, four, six, three, seven, eight, nine, five,
# Nearest to he: it, she, they, who, there, whorf, which, later,
# Nearest to no: vives, or, medline, any, entre, not, yang, butyl,
# Nearest to be: have, been, is, penfield, become, was, by, are,
# Nearest to such: well, beatle, many, these, feldman, lange, special, glassware,
# Nearest to most: use, pigpen, more, all, many, turnpike, some, nueva,
# Nearest to history: petition, chromic, divides, theories, cliffordadams, computer, tackle, xbox,
# Nearest to their: his, its, the, her, these, some, riichi, many,
# Nearest to but: although, however, which, and, though, that, would, vignettes,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Average loss at step 22000: 3.500046
# Average loss at step 24000: 3.488270
# Average loss at step 26000: 3.486683
# Average loss at step 28000: 3.479520
# Average loss at step 30000: 3.500391
# Nearest to three: five, four, seven, eight, six, two, zero, nine,
# Nearest to if: when, where, minimalist, should, since, but, showed, halpin,
# Nearest to a: any, no, ltcm, jardines, shel, every, suggestibility, deutschen,
# Nearest to united: chakra, djing, hydroponics, insurance, diedrich, soleil, infrastructures, sinister,
# Nearest to often: sometimes, generally, also, there, still, unambiguously, conservationist, usually,
# Nearest to they: we, he, there, you, who, not, it, these,
# Nearest to one: two, four, seven, eight, five, three, six, nine,
# Nearest to he: she, it, they, who, there, whorf, authenticity, tighter,
# Nearest to no: any, vives, still, a, polonium, medline, battista, butyl,
# Nearest to be: been, have, is, become, penfield, pervasive, partnering, was,
# Nearest to such: well, these, known, like, many, feldman, some, romanorum,
# Nearest to most: more, use, pigpen, many, some, apostol, nueva, turnpike,
# Nearest to history: library, theories, huddle, xbox, chromic, aloof, axis, divides,
# Nearest to their: his, its, the, her, these, many, some, riichi,
# Nearest to but: however, although, while, and, that, which, though, he,
# Nearest to nine: eight, seven, six, five, four, three, zero, births,
# Average loss at step 32000: 3.501715
# Average loss at step 34000: 3.488674
# Average loss at step 36000: 3.456981
# Average loss at step 38000: 3.300279
# Average loss at step 40000: 3.431831
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to if: when, where, is, disguises, because, minimalist, governorship, scalp,
# Nearest to a: the, any, another, no, shel, or, granville, innovators,
# Nearest to united: chakra, djing, hydroponics, diedrich, diner, infrastructures, mysia, southern,
# Nearest to often: sometimes, generally, usually, also, still, commonly, there, frequently,
# Nearest to they: we, you, he, there, it, who, she, not,
# Nearest to one: seven, four, eight, two, six, five, three, nine,
# Nearest to he: it, she, they, who, there, later, i, tighter,
# Nearest to no: any, or, a, vives, still, medline, magnetization, malignancies,
# Nearest to be: been, have, were, was, is, become, are, being,
# Nearest to such: well, these, known, saskatoon, superhero, many, beatle, gb,
# Nearest to most: more, many, pigpen, reconstruction, use, apostol, some, togo,
# Nearest to history: sums, ebbets, ecuadorean, tenacity, form, unfit, axis, theories,
# Nearest to their: its, his, her, the, riichi, your, these, some,
# Nearest to but: however, although, while, which, and, though, where, when,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Average loss at step 42000: 3.438282
# Average loss at step 44000: 3.452140
# Average loss at step 46000: 3.452459
# Average loss at step 48000: 3.353163
# Average loss at step 50000: 3.383526
# Nearest to three: six, four, seven, eight, five, nine, two, zero,
# Nearest to if: when, where, before, since, scalp, although, should, disguises,
# Nearest to a: the, another, any, shel, failures, boulevard, no, roden,
# Nearest to united: djing, chakra, hydroponics, infrastructures, syrian, southern, mysia, diedrich,
# Nearest to often: sometimes, generally, usually, commonly, still, frequently, also, now,
# Nearest to they: he, we, there, you, it, she, these, who,
# Nearest to one: two, six, four, eight, three, seven, five, nine,
# Nearest to he: she, it, they, there, who, whorf, nuit, nuova,
# Nearest to no: any, a, sentry, consorts, battista, simulators, magnetization, chieftain,
# Nearest to be: were, been, have, was, is, are, become, partnering,
# Nearest to such: well, these, many, known, superhero, equivocation, saskatoon, intrauterine,
# Nearest to most: more, many, reconstruction, less, use, apostol, pigpen, turnpike,
# Nearest to history: sums, unfit, mems, span, maxima, ecuadorean, tenacity, mosque,
# Nearest to their: its, his, her, the, mysore, our, these, your,
# Nearest to but: however, although, though, while, and, where, when, since,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Average loss at step 52000: 3.433182
# Average loss at step 54000: 3.428478
# Average loss at step 56000: 3.437756
# Average loss at step 58000: 3.394547
# Average loss at step 60000: 3.391157
# Nearest to three: five, four, six, eight, two, seven, nine, zero,
# Nearest to if: when, where, before, though, because, since, should, so,
# Nearest to a: any, the, another, every, innovators, shel, no, ingesting,
# Nearest to united: chakra, djing, hydroponics, syrian, infrastructures, medley, diedrich, mysia,
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, also, now,
# Nearest to they: we, you, there, he, she, these, it, i,
# Nearest to one: four, two, six, eight, seven, five, three, nine,
# Nearest to he: she, it, they, there, whorf, who, nuova, we,
# Nearest to no: any, consorts, a, little, chieftain, kearney, vous, codes,
# Nearest to be: been, have, is, become, were, partnering, erlang, are,
# Nearest to such: well, these, known, many, superhero, including, saskatoon, intrauterine,
# Nearest to most: more, many, some, less, use, reconstruction, pigpen, all,
# Nearest to history: list, politics, ecuadorean, huddle, antagonist, corvettes, movements, rights,
# Nearest to their: its, his, her, the, our, whose, demographic, your,
# Nearest to but: however, although, and, though, which, while, see, when,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Average loss at step 62000: 3.234124
# Average loss at step 64000: 3.254733
# Average loss at step 66000: 3.401987
# Average loss at step 68000: 3.392400
# Average loss at step 70000: 3.354513
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to if: when, though, where, before, since, while, because, should,
# Nearest to a: the, another, any, twinning, shel, every, psalter, amounts,
# Nearest to united: chakra, djing, hydroponics, syrian, infrastructures, following, tamerlane, diner,
# Nearest to often: sometimes, usually, generally, commonly, frequently, also, now, still,
# Nearest to they: we, he, there, you, she, it, actually, these,
# Nearest to one: six, two, seven, four, five, eight, three, nine,
# Nearest to he: she, it, they, who, there, whorf, nuova, we,
# Nearest to no: any, consorts, little, there, beaked, sentry, codes, demeter,
# Nearest to be: been, become, were, is, are, have, being, partnering,
# Nearest to such: well, these, known, superhero, many, equivocation, separate, generalization,
# Nearest to most: more, many, less, reconstruction, some, quartering, lingered, steadfastly,
# Nearest to history: list, biblical, assassination, redesignated, nolan, corvettes, hbk, ecuadorean,
# Nearest to their: its, his, her, the, our, some, your, these,
# Nearest to but: however, although, though, which, that, and, actually, while,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Average loss at step 72000: 3.374199
# Average loss at step 74000: 3.350004
# Average loss at step 76000: 3.312426
# Average loss at step 78000: 3.347111
# Average loss at step 80000: 3.376940
# Nearest to three: four, five, six, seven, two, eight, zero, nine,
# Nearest to if: when, though, before, since, where, because, did, should,
# Nearest to a: the, every, another, roden, operators, deutschen, shel, gabal,
# Nearest to united: chakra, djing, hydroponics, infrastructures, syrian, forbade, athletic, confining,
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, now, rarely,
# Nearest to they: we, he, there, you, she, it, these, actually,
# Nearest to one: seven, six, two, eight, four, three, five, nine,
# Nearest to he: she, it, they, there, who, nuova, we, browed,
# Nearest to no: little, any, sentry, consorts, beaked, codes, bested, mithra,
# Nearest to be: been, become, have, partnering, being, were, refer, nanda,
# Nearest to such: well, these, known, superhero, certain, including, defined, separate,
# Nearest to most: more, many, less, reconstruction, some, among, apostol, especially,
# Nearest to history: list, hbk, emperors, nightmare, corvettes, ecuadorean, tenacity, historical,
# Nearest to their: its, his, her, our, your, the, whose, these,
# Nearest to but: however, although, though, while, and, see, mecha, or,
# Nearest to nine: eight, seven, six, five, four, three, zero, births,
# Average loss at step 82000: 3.410170
# Average loss at step 84000: 3.409590
# Average loss at step 86000: 3.392083
# Average loss at step 88000: 3.350390
# Average loss at step 90000: 3.363069
# Nearest to three: four, five, two, seven, six, eight, nine, zero,
# Nearest to if: when, since, though, before, where, after, refuted, scalp,
# Nearest to a: roden, every, another, woogie, any, the, ltcm, caplan,
# Nearest to united: chakra, djing, following, constitution, hydroponics, infrastructures, syrian, tenth,
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, now, rarely,
# Nearest to they: we, he, there, you, she, it, not, who,
# Nearest to one: seven, four, two, eight, six, five, three, nine,
# Nearest to he: she, it, they, there, who, whorf, browed, later,
# Nearest to no: little, any, specimen, only, sentry, undeniable, characterizing, codes,
# Nearest to be: been, become, have, is, was, refer, being, zubaydah,
# Nearest to such: well, known, these, superhero, certain, many, separate, opposed,
# Nearest to most: more, less, many, some, among, reconstruction, particularly, especially,
# Nearest to history: list, hbk, nightmare, mormon, huddle, ezquerra, krs, corvettes,
# Nearest to their: his, its, her, our, your, the, whose, some,
# Nearest to but: however, although, and, though, while, honecker, he, which,
# Nearest to nine: seven, eight, six, five, four, zero, three, births,
# Average loss at step 92000: 3.398418
# Average loss at step 94000: 3.253503
# Average loss at step 96000: 3.354896
# Average loss at step 98000: 3.242361
# Average loss at step 100000: 3.354259
# Nearest to three: four, five, seven, six, eight, two, nine, zero,
# Nearest to if: when, though, before, since, where, while, so, after,
# Nearest to a: another, any, the, roden, gabal, ltcm, woogie, shel,
# Nearest to united: chakra, djing, infrastructures, following, hydroponics, constitution, tenth, syrian,
# Nearest to often: usually, sometimes, generally, commonly, frequently, rarely, typically, actually,
# Nearest to they: we, he, there, you, she, it, i, not,
# Nearest to one: two, four, six, seven, five, eight, nine, three,
# Nearest to he: she, it, they, there, we, who, never, whorf,
# Nearest to no: any, little, only, codes, advocacy, sentry, there, chill,
# Nearest to be: been, become, have, partnering, refer, erlang, being, is,
# Nearest to such: well, known, these, superhero, separate, certain, many, opposed,
# Nearest to most: more, less, especially, reconstruction, apostol, among, many, particularly,
# Nearest to history: list, hbk, nightmare, span, biblical, ezquerra, moselle, courtenay,
# Nearest to their: its, his, her, our, your, the, these, whose,
# Nearest to but: however, although, and, though, while, when, where, gator,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_cbow_batch(batch_size, num_cbows, cbow_window):
  global data_index
  assert batch_size % num_cbows == 0
  assert num_cbows <= 2 * cbow_window
  flat_batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size//num_cbows, 1), dtype=np.int32)
  span = 2 * cbow_window + 1 # [ cbow_window target cbow_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_cbows):
    target = cbow_window  # target label at the center of the buffer
    targets_to_avoid = [ cbow_window ]
    for j in range(num_cbows):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      flat_batch[i * num_cbows + j] = buffer[target]
    labels[i, 0] = buffer[cbow_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    batch = flat_batch.reshape((-1,num_cbows))
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_cbows, cbow_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_cbow_batch(batch_size=8, num_cbows=num_cbows, cbow_window=cbow_window)
    print('\nwith num_cbows = %d and cbow_window = %d:' % (num_cbows, cbow_window))
    
    print('    batch:', [[reverse_dictionary[bij] for bij in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8//num_cbows)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_cbows = 2 and cbow_window = 1:
#     batch: [['anarchism', 'as'], ['a', 'originated'], ['as', 'term'], ['of', 'a']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_cbows = 4 and cbow_window = 2:
#     batch: [['term', 'a', 'anarchism', 'originated'], ['as', 'term', 'of', 'originated']]
#     labels: ['as', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
cbow_window = 1 # How many words to consider left and right.
num_cbows = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  #train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  #train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size//num_cbows,num_cbows])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size//num_cbows, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.reduce_sum(tf.nn.embedding_lookup(embeddings, train_dataset), [1])

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, num_cbows, cbow_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.969235
# Nearest to known: courtenay, maori, neptunian, festivities, dutchman, tyson, militaries, timur,
# Nearest to can: inteligencia, liberal, universitet, somoza, webpage, hannover, uplifted, pang,
# Nearest to so: bernadette, affirmed, shortened, vest, unofficial, implicitly, toward, fluent,
# Nearest to more: daime, junkie, litre, links, laoco, dancing, edifices, influential,
# Nearest to time: najibullah, mystics, regime, correlated, travancore, endeavour, synchronized, canaanite,
# Nearest to six: christianization, hbk, edt, palme, trichloride, angilbert, bogged, island,
# Nearest to new: eligibility, sidi, englewood, lepidus, emancipated, raya, plated, bottled,
# Nearest to zero: bijapur, arras, mule, mapquest, qin, jordanian, witches, kumquats,
# Nearest to also: gm, refrains, playlists, penang, duomo, fra, arians, han,
# Nearest to or: teatro, bootstrapping, szlachta, respectfully, crystallized, hagi, zapatistas, divert,
# Nearest to he: fruiting, reforestation, paolo, claudel, stative, foodcrops, deserted, overdosing,
# Nearest to over: gaff, cathedral, aloe, recourse, camouflage, lawrencium, spins, turbine,
# Nearest to b: misty, pilgrimage, fungal, unnecessary, gory, reflectivity, mah, pons,
# Nearest to between: dih, dion, gimlin, basset, hasbro, diadem, archaically, roden,
# Nearest to for: activist, constans, cupboard, ranching, salamanca, erik, ssc, muslim,
# Nearest to an: misfortune, commercialization, hose, rapping, prized, ons, cordell, slag,
# Average loss at step 2000: 4.224950
# Average loss at step 4000: 3.644129
# Average loss at step 6000: 3.532861
# Average loss at step 8000: 3.388958
# Average loss at step 10000: 3.292112
# Nearest to known: such, used, courtenay, well, defined, cowboy, agis, militaries,
# Nearest to can: may, would, must, will, should, could, oscilloscope, is,
# Nearest to so: bernadette, cougars, hengest, depending, awkward, delusion, originally, commissioning,
# Nearest to more: less, most, stewards, manifestation, rather, litre, wolfe, extrapolated,
# Nearest to time: vincendeau, fact, xof, moors, synchronized, tears, day, head,
# Nearest to six: seven, eight, five, four, zero, three, nine, two,
# Nearest to new: narrators, eligibility, fictional, maybe, plateaus, previous, felsic, hairpin,
# Nearest to zero: eight, nine, six, seven, five, three, four, two,
# Nearest to also: often, usually, generally, sometimes, cobalt, commonly, plano, which,
# Nearest to or: heaters, announcers, multipurpose, lovers, hospitable, kirchenmusik, intents, and,
# Nearest to he: she, it, they, who, salomon, there, but, connectedness,
# Nearest to over: einsteinium, on, negate, archers, morpheus, neorealism, aloe, husband,
# Nearest to b: d, fungal, f, corroborated, selfishness, andrei, kochi, echelon,
# Nearest to between: fils, on, sneak, in, bipeds, including, dion, daydream,
# Nearest to for: withdrawals, knife, grammars, invalid, knapp, locusts, with, unu,
# Nearest to an: gees, the, deadly, aryan, ons, megatokyo, verifies, troughs,
# Average loss at step 12000: 3.273714
# Average loss at step 14000: 3.233805
# Average loss at step 16000: 3.026130
# Average loss at step 18000: 3.056762
# Average loss at step 20000: 3.159966
# Nearest to known: used, regarded, such, defined, opposed, called, courtenay, caledonians,
# Nearest to can: may, would, will, could, should, must, cannot, might,
# Nearest to so: too, bernadette, curtain, ulrich, depending, memorable, mafia, hengest,
# Nearest to more: less, most, very, rather, greater, granted, prima, extremely,
# Nearest to time: way, years, year, possibility, moors, president, schloss, jamil,
# Nearest to six: seven, nine, zero, five, four, eight, two, three,
# Nearest to new: hairpin, western, antes, hysteria, plated, pty, major, dependence,
# Nearest to zero: six, five, seven, nine, eight, four, three, two,
# Nearest to also: sometimes, not, now, often, then, never, commonly, which,
# Nearest to or: and, than, industrially, cancels, lauter, with, dismal, mistresses,
# Nearest to he: she, it, they, there, who, never, then, patchwork,
# Nearest to over: neorealism, inquest, einsteinium, ecologists, chydenius, wayne, into, fluorite,
# Nearest to b: d, actor, selfishness, gonzales, mail, dilmun, andrei, ign,
# Nearest to between: fils, within, including, with, tripled, fenian, daydream, against,
# Nearest to for: of, majlis, locusts, starry, by, gs, yerushalmi, entire,
# Nearest to an: aryan, the, patchwork, morons, ons, gees, slag, loti,
# Average loss at step 22000: 3.122061
# Average loss at step 24000: 3.078202
# Average loss at step 26000: 3.061118
# Average loss at step 28000: 3.075240
# Average loss at step 30000: 3.081706
# Nearest to known: used, opposed, well, regarded, defined, served, recognized, see,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to so: too, bernadette, dissatisfied, ft, memorable, curtain, clandestine, petra,
# Nearest to more: less, rather, greater, very, larger, barclay, highly, smaller,
# Nearest to time: place, year, way, period, knowledge, possibility, belief, moors,
# Nearest to six: eight, four, nine, seven, five, three, zero, two,
# Nearest to new: hairpin, major, real, separate, second, fictional, directive, modern,
# Nearest to zero: eight, seven, five, nine, six, three, four, two,
# Nearest to also: often, now, sometimes, never, already, generally, actually, still,
# Nearest to or: and, kava, vanished, pye, domingue, brocklin, than, canossa,
# Nearest to he: she, it, they, there, who, never, eventually, psyche,
# Nearest to over: up, off, lumen, geosynchronous, neorealism, einsteinium, reincarnation, through,
# Nearest to b: d, paralipomena, philadelphia, supposes, aaas, nay, bester, levine,
# Nearest to between: with, elementals, under, against, morehouse, from, fils, mich,
# Nearest to for: with, including, when, dyess, while, of, after, esc,
# Nearest to an: graveyard, rapping, lehman, gees, deadly, troughs, slag, kalevala,
# Average loss at step 32000: 3.085209
# Average loss at step 34000: 3.051232
# Average loss at step 36000: 2.994563
# Average loss at step 38000: 2.792633
# Average loss at step 40000: 2.978931
# Nearest to known: used, such, possible, well, defined, opposed, regarded, recognized,
# Nearest to can: may, could, will, must, would, should, might, cannot,
# Nearest to so: laos, too, more, curtain, zurich, mafia, emphasis, less,
# Nearest to more: less, most, greater, rather, very, highly, larger, so,
# Nearest to time: way, year, person, period, cosmetics, belief, spaceflights, aeacus,
# Nearest to six: eight, four, seven, nine, five, three, two, zero,
# Nearest to new: modern, harnessing, separate, major, artcyclopedia, hairpin, maclennan, palette,
# Nearest to zero: seven, five, nine, eight, six, three, four, two,
# Nearest to also: often, sometimes, usually, typically, still, now, generally, commonly,
# Nearest to or: and, than, misplaced, rameau, tammy, janssen, minus, cayuga,
# Nearest to he: she, it, they, there, who, i, salomon, gradually,
# Nearest to over: inquest, stratford, about, chattanooga, into, all, full, idealist,
# Nearest to b: d, c, ichij, qf, cecil, jingle, nchez, masochism,
# Nearest to between: with, sneak, from, accented, outside, during, within, mich,
# Nearest to for: against, after, with, of, by, transformer, griese, when,
# Nearest to an: deadly, patchwork, mackaye, ons, another, voce, shiga, rebuttal,
# Average loss at step 42000: 2.984545
# Average loss at step 44000: 2.992481
# Average loss at step 46000: 2.983455
# Average loss at step 48000: 2.870729
# Average loss at step 50000: 2.897504
# Nearest to known: used, defined, such, possible, regarded, recognized, well, famous,
# Nearest to can: could, may, must, should, will, cannot, would, might,
# Nearest to so: too, curtain, before, pacemakers, confocal, misconception, disappear, supposedly,
# Nearest to more: less, highly, rather, very, greater, most, larger, quite,
# Nearest to time: year, way, period, spaceflights, day, analogs, entrenched, place,
# Nearest to six: seven, eight, nine, three, four, five, zero, two,
# Nearest to new: different, isaurian, hysteria, fictional, ged, hungarian, hairpin, local,
# Nearest to zero: seven, six, five, nine, eight, four, three, two,
# Nearest to also: often, now, typically, sometimes, still, hafnium, which, actually,
# Nearest to or: and, ulysses, like, counterfeit, pentagons, polgar, but, kalashnikov,
# Nearest to he: she, it, they, who, there, eventually, then, spears,
# Nearest to over: on, concertos, about, into, through, sensation, up, deriving,
# Nearest to b: d, qf, warped, c, tampa, f, idb, wedge,
# Nearest to between: with, najd, among, against, sneak, across, diskette, auteurs,
# Nearest to for: dyess, while, against, blaylock, modular, during, disrespectful, bottlers,
# Nearest to an: another, deadly, slag, kalevala, no, wraps, ons, the,
# Average loss at step 52000: 2.960534
# Average loss at step 54000: 2.935421
# Average loss at step 56000: 2.957389
# Average loss at step 58000: 2.876304
# Average loss at step 60000: 2.892405
# Nearest to known: used, defined, regarded, considered, understood, possible, opposed, such,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to so: too, curtain, mafia, something, note, imagines, ascended, sometimes,
# Nearest to more: less, rather, larger, quite, very, fairly, highly, smaller,
# Nearest to time: year, round, moors, aeacus, twinned, way, week, place,
# Nearest to six: nine, five, eight, four, seven, three, zero, two,
# Nearest to new: previous, fictional, third, authorisation, federal, separate, hungarian, recent,
# Nearest to zero: five, six, eight, four, nine, seven, three, two,
# Nearest to also: now, often, still, actually, usually, generally, sometimes, never,
# Nearest to or: and, pentagons, measles, syndication, cauca, gauguin, thermochemistry, clothing,
# Nearest to he: she, it, they, there, rationalized, eventually, gradually, we,
# Nearest to over: within, across, around, palladius, acetylene, about, without, through,
# Nearest to b: c, r, f, d, h, qf, tampa, p,
# Nearest to between: among, with, against, within, elementals, across, najd, through,
# Nearest to for: of, including, although, orthographic, against, modular, formal, without,
# Nearest to an: gees, mackaye, bytecode, greenspan, centerline, kalevala, nguni, ons,
# Average loss at step 62000: 2.681107
# Average loss at step 64000: 2.701914
# Average loss at step 66000: 2.883499
# Average loss at step 68000: 2.894013
# Average loss at step 70000: 2.843720
# Nearest to known: defined, regarded, used, understood, considered, such, described, recognized,
# Nearest to can: could, may, might, should, must, would, will, cannot,
# Nearest to so: then, too, sometimes, how, bak, strictly, thus, ft,
# Nearest to more: less, rather, most, larger, very, too, quite, fairly,
# Nearest to time: year, moors, almaty, decade, gerais, debate, aeacus, decades,
# Nearest to six: eight, nine, seven, five, four, three, two, zero,
# Nearest to new: fictional, tov, navigator, old, authorisation, amputation, coloration, garbage,
# Nearest to zero: eight, five, seven, six, nine, four, three, million,
# Nearest to also: still, now, never, actually, usually, sometimes, which, often,
# Nearest to or: and, pentagons, must, dimensional, impeccable, kalashnikov, landsmannschaft, mazes,
# Nearest to he: she, it, they, there, spears, eventually, subsequently, gradually,
# Nearest to over: within, around, palladius, about, across, acetylene, lumen, full,
# Nearest to b: r, f, d, emulsifiers, h, y, morningside, eug,
# Nearest to between: among, within, elementals, with, across, regarding, insulinotherapy, mich,
# Nearest to for: against, in, after, where, if, freyr, of, esc,
# Nearest to an: slag, kalevala, gees, greenspan, patchwork, bytecode, mackaye, no,
# Average loss at step 72000: 2.860245
# Average loss at step 74000: 2.824261
# Average loss at step 76000: 2.824334
# Average loss at step 78000: 2.825259
# Average loss at step 80000: 2.847183
# Nearest to known: defined, used, called, regarded, considered, described, understood, recognized,
# Nearest to can: will, could, may, would, should, must, cannot, might,
# Nearest to so: too, mafia, visigoth, manoeuvres, imagines, monies, askari, disappear,
# Nearest to more: less, rather, larger, very, smaller, fairly, quite, most,
# Nearest to time: year, moors, aeacus, extent, decade, latvians, vincendeau, decades,
# Nearest to six: five, seven, four, eight, three, nine, zero, two,
# Nearest to new: previous, fictional, linguistic, hairpin, friendships, old, reels, hungarian,
# Nearest to zero: seven, eight, six, five, four, three, nine, two,
# Nearest to also: actually, never, now, still, sometimes, often, typically, which,
# Nearest to or: and, though, phage, but, pivots, unbound, than, judaica,
# Nearest to he: she, it, they, who, we, there, never, originally,
# Nearest to over: within, across, around, inquest, between, auteurs, lumen, off,
# Nearest to b: c, d, eug, emulsifiers, ballet, qf, maxillofacial, r,
# Nearest to between: among, within, across, with, mich, najd, regulates, elementals,
# Nearest to for: ica, in, emergent, betray, counterfeiting, targeting, locusts, preservatives,
# Nearest to an: gees, deadly, kalevala, ons, slag, rutland, another, greenspan,
# Average loss at step 82000: 2.888445
# Average loss at step 84000: 2.899426
# Average loss at step 86000: 2.853692
# Average loss at step 88000: 2.808183
# Average loss at step 90000: 2.821397
# Nearest to known: used, defined, understood, such, described, opposed, possible, regarded,
# Nearest to can: might, will, may, could, should, would, cannot, must,
# Nearest to so: too, encrusted, felt, buren, mafia, if, thus, imagines,
# Nearest to more: less, rather, larger, very, greater, smaller, longer, fairly,
# Nearest to time: decade, year, aeacus, unlikely, moors, sort, reason, debate,
# Nearest to six: eight, seven, four, five, nine, zero, three, two,
# Nearest to new: previous, blogger, separate, welded, militarist, particular, corgi, different,
# Nearest to zero: seven, six, eight, five, four, nine, three, million,
# Nearest to also: actually, never, often, now, still, generally, sometimes, therefore,
# Nearest to or: and, pentagons, brocklin, daisies, than, gauguin, including, overheat,
# Nearest to he: she, it, they, there, who, originally, chaplin, smith,
# Nearest to over: around, off, within, between, inquest, across, out, about,
# Nearest to b: d, forging, safe, tampa, emulsifiers, eug, c, qf,
# Nearest to between: among, within, across, with, auteurs, against, over, from,
# Nearest to for: of, against, after, including, without, when, fayed, under,
# Nearest to an: kalevala, mackaye, ons, voce, guan, bytecode, deadly, gees,
# Average loss at step 92000: 2.863207
# Average loss at step 94000: 2.691991
# Average loss at step 96000: 2.832565
# Average loss at step 98000: 2.690230
# Average loss at step 100000: 2.819353
# Nearest to known: defined, possible, such, regarded, opposed, understood, described, accepted,
# Nearest to can: may, could, might, cannot, would, must, should, will,
# Nearest to so: too, thus, then, imagines, eventually, visigoth, later, serpent,
# Nearest to more: less, very, fairly, most, greater, longer, larger, smaller,
# Nearest to time: year, sort, manner, extent, decade, debate, moors, ilium,
# Nearest to six: five, four, seven, nine, eight, three, zero, two,
# Nearest to new: different, previous, specific, separate, garbage, modern, orally, multi,
# Nearest to zero: seven, nine, eight, six, four, five, three, two,
# Nearest to also: actually, never, now, sometimes, traditionally, often, typically, still,
# Nearest to or: and, than, hypnotic, pentagons, andrade, flickering, heaters, sheba,
# Nearest to he: she, it, they, we, there, who, never, publicly,
# Nearest to over: osborn, within, inquest, around, between, across, about, kidnappers,
# Nearest to b: d, c, cheech, hvac, hampering, boyfriend, publicised, gunn,
# Nearest to between: among, against, across, with, najd, mich, within, elementals,
# Nearest to for: including, when, before, after, during, consider, although, emanuel,
# Nearest to an: ons, laertius, gees, guan, troughs, slag, voce, cub,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
