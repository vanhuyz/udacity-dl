# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
a = dict()
print(a)
# Out:
# {}

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])

del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.470851
# Nearest to some: figaro, nepeta, anthropomorphized, diffuses, vows, cart, viscount, assessing,
# Nearest to people: college, pensacola, collage, shave, suppressive, womanizer, demonym, madman,
# Nearest to or: pans, andrei, konerko, bandits, quarterbacks, reworking, navel, beautifully,
# Nearest to four: accusations, ab, nunavut, bi, siwa, sabine, infringement, noticing,
# Nearest to can: akm, publishers, airshows, wwii, unleashing, canterbury, westphalia, edit,
# Nearest to often: balloon, permian, earnings, bullpen, devastation, eur, poses, fricative,
# Nearest to that: canon, stream, aida, crichton, eoka, plasmids, generated, fughetta,
# Nearest to may: juggalo, safest, ulbricht, schlesinger, tapering, fullwidth, sculpted, immersed,
# Nearest to war: bevan, habitation, specialization, unfair, briand, gelatinous, prompts, secretariat,
# Nearest to however: neman, val, parliamentarians, subterranean, secretion, dystopia, apprehend, illusion,
# Nearest to three: vogt, prevail, browsing, macmanus, ayrton, ignorance, uthman, defending,
# Nearest to american: acs, advisory, alessandri, schodt, pronounced, inward, atmospheric, polemics,
# Nearest to no: swivel, rembrandt, suzerainty, carbonate, intruders, mithra, ncaa, chimp,
# Nearest to which: schriften, hofmann, codomain, nigeria, guinevere, xcd, sirhan, shabazz,
# Nearest to as: elegy, untersuchungen, etruria, chapterhouse, lethe, parishes, inhibitor, definable,
# Nearest to over: shade, count, intermarried, hurled, blossoms, comically, slew, proteases,
# Average loss at step 2000: 4.348442
# Average loss at step 4000: 3.866777
# Average loss at step 6000: 3.853054
# Average loss at step 8000: 3.728647
# Average loss at step 10000: 3.558607
# Nearest to some: many, nepeta, this, conforms, airstream, felix, domenico, troll,
# Nearest to people: college, collage, tanganyika, piracy, halogens, bnf, charging, johann,
# Nearest to or: and, pans, icbms, luncheon, supposing, hao, ller, pants,
# Nearest to four: five, seven, eight, three, six, nine, zero, two,
# Nearest to can: would, may, will, lionel, fredrik, oj, could, should,
# Nearest to often: also, usually, permian, not, triadic, himmel, balloon, earnings,
# Nearest to that: which, this, riaa, it, weyl, winfrey, also, factors,
# Nearest to may: can, would, must, gorky, cellphone, dhyana, atlanta, juggalo,
# Nearest to war: tour, bundestag, bevan, alonzo, monastics, didactic, synchronised, alexandrian,
# Nearest to however: parliamentarians, stating, yag, val, xaver, obtainable, neman, dystopia,
# Nearest to three: eight, five, four, six, seven, two, nine, one,
# Nearest to american: antonius, qadhafi, boa, pollute, bebop, advisory, international, acs,
# Nearest to no: pinus, icbms, jo, it, sledge, marilyn, mcnamara, veer,
# Nearest to which: that, it, this, also, misr, murr, aspirin, alsatian,
# Nearest to as: squealer, scottsdale, hamish, recognizes, cosa, mayhem, second, stefan,
# Nearest to over: blossoms, amharic, moncada, super, casablanca, within, count, comically,
# Average loss at step 12000: 3.634236
# Average loss at step 14000: 3.601081
# Average loss at step 16000: 3.610853
# Average loss at step 18000: 3.587841
# Average loss at step 20000: 3.533333
# Nearest to some: many, these, all, nepeta, enlist, other, those, witold,
# Nearest to people: mactutor, bnf, demonym, wine, college, cruel, piracy, gram,
# Nearest to or: and, obsoletes, shaw, cir, ineffectiveness, peachtree, occ, northside,
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# Nearest to can: may, will, would, could, should, must, cannot, fredrik,
# Nearest to often: usually, also, still, balloon, not, normally, himmel, jg,
# Nearest to that: which, what, fin, this, prologue, however, fart, academic,
# Nearest to may: can, would, could, must, will, should, might, analysing,
# Nearest to war: delightful, buckets, synchronised, bevan, bundestag, proton, tour, yokohama,
# Nearest to however: but, rupee, parliamentarians, stating, xaver, workflow, galleries, that,
# Nearest to three: four, five, two, eight, six, seven, nine, zero,
# Nearest to american: british, antonius, lonesome, qadhafi, origami, bebop, international, festival,
# Nearest to no: jo, ulam, sledge, it, mcnamara, marilyn, another, there,
# Nearest to which: that, this, also, it, misr, diglossia, flavours, wasp,
# Nearest to as: ordained, without, commonly, squealer, ciboney, by, scottsdale, suppressive,
# Nearest to over: within, blossoms, ships, amharic, casablanca, comically, super, count,
# Average loss at step 22000: 3.487152
# Average loss at step 24000: 3.479497
# Average loss at step 26000: 3.388715
# Average loss at step 28000: 3.513835
# Average loss at step 30000: 3.396153
# Nearest to some: many, these, all, various, other, several, their, advanced,
# Nearest to people: wine, men, decomposers, mactutor, cruel, relationships, arsenate, bnf,
# Nearest to or: and, fr, than, evaporation, kames, pans, authoritarian, determines,
# Nearest to four: five, three, seven, six, eight, two, nine, zero,
# Nearest to can: may, will, would, could, should, must, cannot, might,
# Nearest to often: usually, also, still, which, generally, always, normally, commonly,
# Nearest to that: which, this, witch, however, eventually, fin, where, what,
# Nearest to may: can, would, will, could, must, should, might, gorky,
# Nearest to war: bundestag, delightful, synchronised, buckets, horror, tour, kickoffs, orbitals,
# Nearest to however: but, although, though, while, when, that, parliamentarians, biostatistics,
# Nearest to three: four, seven, five, six, eight, two, nine, zero,
# Nearest to american: british, english, french, necrosis, origami, german, acs, passover,
# Nearest to no: another, any, a, marilyn, jo, there, mcnamara, ulam,
# Nearest to which: that, this, also, it, often, who, eventually, never,
# Nearest to as: mayhem, sued, penitent, sowell, shuffled, pdas, by, celestine,
# Nearest to over: within, blossoms, casablanca, comically, ships, amharic, moncada, from,
# Average loss at step 32000: 3.393073
# Average loss at step 34000: 3.413707
# Average loss at step 36000: 3.423906
# Average loss at step 38000: 3.480409
# Average loss at step 40000: 3.424410
# Nearest to some: many, these, all, various, several, other, the, any,
# Nearest to people: men, wine, decomposers, players, women, years, coronation, ladas,
# Nearest to or: and, but, cir, ineffectiveness, bartle, than, obsoletes, abv,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to often: usually, still, commonly, also, generally, sometimes, widely, normally,
# Nearest to that: which, what, however, this, where, sarcasm, canon, witch,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to war: bundestag, buckets, synchronised, tour, delightful, beautiful, outlet, kickoffs,
# Nearest to however: but, although, while, that, world, though, there, during,
# Nearest to three: four, five, six, two, eight, seven, zero, nine,
# Nearest to american: british, international, badges, chopped, english, synchronize, origami, festival,
# Nearest to no: any, uncompressed, lodging, mcnamara, hive, another, ulam, marilyn,
# Nearest to which: that, this, it, there, also, but, typically, where,
# Nearest to as: mayhem, pdas, masamune, ciboney, shuffled, eccentric, ordained, budgeted,
# Nearest to over: within, through, casablanca, blossoms, amharic, moncada, comically, out,
# Average loss at step 42000: 3.443749
# Average loss at step 44000: 3.235857
# Average loss at step 46000: 3.450599
# Average loss at step 48000: 3.417050
# Average loss at step 50000: 3.453577
# Nearest to some: many, several, these, various, any, all, borer, certain,
# Nearest to people: men, children, wine, decomposers, women, prominent, players, deficit,
# Nearest to or: and, than, ller, but, bias, fr, resent, ineffectiveness,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to can: may, will, could, would, must, might, should, cannot,
# Nearest to often: usually, commonly, sometimes, still, generally, also, now, widely,
# Nearest to that: which, however, what, sarcasm, where, how, this, eoka,
# Nearest to may: can, would, must, could, will, should, might, cannot,
# Nearest to war: bundestag, buckets, synchronised, yokohama, tire, dug, tour, kickoffs,
# Nearest to however: but, although, that, though, while, when, remo, there,
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to american: british, german, italian, english, international, french, guevara, festival,
# Nearest to no: any, there, ellington, pads, ulam, lodging, consolidating, uncompressed,
# Nearest to which: that, also, this, what, there, it, who, typically,
# Nearest to as: maoism, mayhem, ordained, liter, stuck, suppressive, masamune, ciboney,
# Nearest to over: within, amharic, blossoms, moncada, through, federated, fenton, constitutional,
# Average loss at step 52000: 3.451089
# Average loss at step 54000: 3.436476
# Average loss at step 56000: 3.378066
# Average loss at step 58000: 3.291637
# Average loss at step 60000: 3.388447
# Nearest to some: many, several, these, all, various, any, their, both,
# Nearest to people: men, children, wine, women, mactutor, peoples, economy, dollar,
# Nearest to or: and, than, but, vorder, endlessly, disturb, sleeping, bias,
# Nearest to four: five, seven, eight, six, three, nine, two, zero,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to often: usually, commonly, sometimes, generally, still, normally, widely, frequently,
# Nearest to that: which, what, this, however, where, how, sarcasm, admirals,
# Nearest to may: can, could, would, must, might, will, should, cannot,
# Nearest to war: bundestag, kickoffs, outlet, mess, tire, dug, buckets, yokohama,
# Nearest to however: but, although, though, while, that, when, until, neighbouring,
# Nearest to three: five, four, eight, two, seven, six, nine, zero,
# Nearest to american: british, international, italian, english, french, guevara, festival, german,
# Nearest to no: any, only, ellington, cps, there, marilyn, belgrade, mcnamara,
# Nearest to which: that, this, also, what, who, it, there, these,
# Nearest to as: mayhem, when, without, liter, theologies, informally, maoism, ciboney,
# Nearest to over: within, ships, across, federated, blossoms, amharic, through, hook,
# Average loss at step 62000: 3.384506
# Average loss at step 64000: 3.382984
# Average loss at step 66000: 3.357070
# Average loss at step 68000: 3.393920
# Average loss at step 70000: 3.362797
# Nearest to some: many, these, several, all, various, certain, most, those,
# Nearest to people: men, children, women, players, peoples, wine, years, dollar,
# Nearest to or: and, than, but, while, like, preview, workstation, with,
# Nearest to four: five, six, eight, seven, nine, three, two, zero,
# Nearest to can: could, will, may, would, must, should, cannot, might,
# Nearest to often: usually, sometimes, still, generally, commonly, normally, frequently, typically,
# Nearest to that: which, however, what, this, mashing, athelstan, admirals, where,
# Nearest to may: can, must, could, would, will, should, might, cannot,
# Nearest to war: kickoffs, tire, mess, yokohama, outlet, bat, bundestag, solnhofen,
# Nearest to however: but, although, though, while, when, that, during, since,
# Nearest to three: two, six, five, four, eight, seven, nine, zero,
# Nearest to american: british, italian, french, german, international, english, festival, guevara,
# Nearest to no: any, another, hive, only, ellington, cps, pads, sioux,
# Nearest to which: that, this, also, what, who, sy, never, based,
# Nearest to as: mayhem, liter, bean, by, informally, ciboney, shuffled, berkowitz,
# Nearest to over: within, across, through, federated, ships, out, amharic, blossoms,
# Average loss at step 72000: 3.401102
# Average loss at step 74000: 3.393883
# Average loss at step 76000: 3.270746
# Average loss at step 78000: 3.324275
# Average loss at step 80000: 3.373295
# Nearest to some: many, several, various, any, both, most, these, all,
# Nearest to people: men, children, women, individuals, players, dollar, caucasus, historians,
# Nearest to or: and, than, but, while, occlusion, per, relating, though,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to can: will, may, could, must, would, cannot, should, might,
# Nearest to often: usually, sometimes, generally, commonly, still, frequently, normally, now,
# Nearest to that: which, however, but, fin, allergy, what, aisha, invariance,
# Nearest to may: can, would, should, will, must, could, might, cannot,
# Nearest to war: tire, synchronised, kickoffs, outlet, ambrosius, mess, bundestag, ayrshire,
# Nearest to however: but, although, though, while, that, when, occur, dispatches,
# Nearest to three: five, two, four, six, seven, nine, eight, one,
# Nearest to american: british, french, english, international, german, italian, canadian, festival,
# Nearest to no: any, only, there, little, another, cps, sioux, hive,
# Nearest to which: that, this, what, also, typically, who, these, but,
# Nearest to as: mayhem, pdas, without, by, celestine, liter, sowell, downer,
# Nearest to over: across, within, about, ships, amharic, blossoms, hammersmith, federated,
# Average loss at step 82000: 3.290748
# Average loss at step 84000: 3.337751
# Average loss at step 86000: 3.326033
# Average loss at step 88000: 3.344415
# Average loss at step 90000: 3.049652
# Nearest to some: many, several, these, various, certain, all, any, most,
# Nearest to people: men, children, women, historians, mactutor, dollar, years, materialistic,
# Nearest to or: and, than, occlusion, ndebele, while, per, vultures, though,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to can: could, will, cannot, would, may, must, should, might,
# Nearest to often: usually, sometimes, generally, still, frequently, commonly, normally, now,
# Nearest to that: which, however, what, sarcasm, prologue, who, thus, where,
# Nearest to may: can, must, would, will, could, might, should, cannot,
# Nearest to war: tire, synchronised, kickoffs, wars, iraq, yokohama, ambrosius, ayrshire,
# Nearest to however: although, but, though, while, that, since, until, when,
# Nearest to three: six, seven, five, four, eight, two, nine, zero,
# Nearest to american: british, english, canadian, german, s, italian, and, french,
# Nearest to no: any, little, fluorine, sioux, hive, golf, vanities, another,
# Nearest to which: that, who, this, also, what, actually, it, never,
# Nearest to as: paltrow, for, liter, mayhem, macias, before, lex, became,
# Nearest to over: ships, across, within, about, hammersmith, intermarried, federated, amharic,
# Average loss at step 92000: 2.822118
# Average loss at step 94000: 3.094195
# Average loss at step 96000: 3.136607
# Average loss at step 98000: 3.260922
# Average loss at step 100000: 3.273680
# Nearest to some: many, several, these, any, all, various, certain, those,
# Nearest to people: men, women, children, historians, americans, peoples, citizens, jews,
# Nearest to or: and, than, facilitates, pasteur, northside, plantarum, occlusion, contested,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to can: could, will, cannot, would, may, must, should, might,
# Nearest to often: usually, sometimes, generally, commonly, frequently, still, also, normally,
# Nearest to that: which, what, however, this, instead, how, where, sarcasm,
# Nearest to may: can, must, could, should, would, might, will, cannot,
# Nearest to war: tire, kickoffs, synchronised, iraq, wars, ayrshire, yokohama, nibelungenlied,
# Nearest to however: but, although, though, while, that, when, today, until,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to american: british, english, canadian, irish, japanese, scottish, australian, french,
# Nearest to no: little, any, another, marilyn, than, only, davis, penitentiary,
# Nearest to which: that, this, what, who, these, also, actually, strongly,
# Nearest to as: mayhem, liter, reasonably, berkowitz, macias, shuffled, pdas, duomo,
# Nearest to over: across, ships, within, off, about, out, through, rebellious,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_cbow_batch(batch_size, num_cbows, cbow_window):
  global data_index
  assert batch_size % num_cbows == 0
  assert num_cbows <= 2 * cbow_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * cbow_window + 1 # [ cbow_window target cbow_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_cbows):
    target = cbow_window  # target label at the center of the buffer
    targets_to_avoid = [ cbow_window ]
    for j in range(num_cbows):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_cbows + j] = buffer[target]
      labels[i * num_cbows + j, 0] = buffer[cbow_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_cbows, cbow_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_cbow_batch(batch_size=8, num_cbows=num_cbows, cbow_window=cbow_window)
    print('\nwith num_cbows = %d and cbow_window = %d:' % (num_cbows, cbow_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_cbows = 2 and cbow_window = 1:
#     batch: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_cbows = 4 and cbow_window = 2:
#     batch: ['a', 'term', 'anarchism', 'originated', 'as', 'term', 'originated', 'of']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
cbow_window = 1 # How many words to consider left and right.
num_cbows = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, num_cbows, cbow_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.773540
# Nearest to can: resembled, warren, worn, commits, vend, operating, observes, ayres,
# Nearest to they: aphex, processes, cofinality, earthly, whistler, sway, sleepy, implemented,
# Nearest to so: appropriating, urey, homeostatic, blames, trinity, mishnaic, notorious, types,
# Nearest to after: frobenius, whispers, exhibit, delphinus, genomes, narnia, grammatik, npr,
# Nearest to the: inspected, maia, ricci, diagnosis, empowered, kb, coimbra, arecibo,
# Nearest to many: oran, homographs, neoclassicism, tattoos, confrontation, gutenberg, attention, evaporation,
# Nearest to between: lamps, uniformed, ergonomics, budweiser, tum, xiongnu, necropolis, verhofstadt,
# Nearest to had: legnica, kursk, technicians, lange, heavier, differentiation, applet, journeyman,
# Nearest to have: ukrainian, anyone, insolvency, desmond, recovering, vyacheslav, crested, undertaken,
# Nearest to his: wicked, cooking, reluctance, rumor, foundation, reforms, alicante, slips,
# Nearest to with: lut, salutation, saltire, hailie, dustin, unwilling, uptime, snowfall,
# Nearest to seven: insulted, mentions, hypotension, lesbians, inlets, breeder, gallus, endanger,
# Nearest to than: unforeseen, sizing, ohrid, meantone, alekhine, ucr, former, paramagnetic,
# Nearest to from: korner, tours, available, mandates, educate, agee, breathes, tans,
# Nearest to s: blamed, bonds, actinides, agra, version, diatoms, poet, luba,
# Nearest to be: bryson, moog, squire, popov, remainder, representations, plasmids, headlining,
# Average loss at step 2000: 4.336867
# Average loss at step 4000: 3.862632
# Average loss at step 6000: 3.591369
# Average loss at step 8000: 3.608619
# Average loss at step 10000: 3.674154
# Nearest to can: will, would, populous, to, may, observes, lucca, resembled,
# Nearest to they: he, we, it, that, yale, rq, there, often,
# Nearest to so: trinity, dispossessed, intense, liturgies, blames, waste, mag, witches,
# Nearest to after: whispers, bibliography, with, delphinus, cris, within, unwavering, myasthenia,
# Nearest to the: his, their, this, its, quetzalcoatl, a, any, havens,
# Nearest to many: several, neoclassicism, some, confrontation, all, distrito, valiantly, memoirs,
# Nearest to between: from, ergonomics, lamps, unadorned, with, fusiliers, fjords, burial,
# Nearest to had: have, has, was, were, collapsed, daytime, durations, took,
# Nearest to have: had, be, has, anyone, militarist, were, preterist, recovering,
# Nearest to his: their, its, the, her, valve, resale, daydream, parodied,
# Nearest to with: for, moore, in, or, lutheranism, by, millennialism, after,
# Nearest to seven: eight, six, nine, three, five, four, zero, two,
# Nearest to than: ohrid, flavianum, sizing, adolphe, single, nnhilde, unforeseen, conversations,
# Nearest to from: between, in, educate, concise, and, aversion, customized, by,
# Nearest to s: charenton, mandated, visigothic, broadcast, remarkable, raider, bes, application,
# Nearest to be: have, was, is, been, sepulchre, propagation, by, bryson,
# Average loss at step 12000: 3.598668
# Average loss at step 14000: 3.579329
# Average loss at step 16000: 3.556711
# Average loss at step 18000: 3.536017
# Average loss at step 20000: 3.571676
# Nearest to can: would, will, may, could, must, should, populous, to,
# Nearest to they: he, we, there, you, it, she, not, who,
# Nearest to so: trinity, waste, dispossessed, intense, if, lanzarote, liturgies, forks,
# Nearest to after: before, when, within, doves, whispers, oregon, unwavering, waldseem,
# Nearest to the: their, his, its, a, many, ack, pell, some,
# Nearest to many: some, several, these, much, distrito, valiantly, bose, confrontation,
# Nearest to between: from, with, lamps, on, fusiliers, unadorned, ergonomics, under,
# Nearest to had: has, have, was, were, backside, annan, saw, got,
# Nearest to have: had, has, were, are, be, militarist, preterist, saw,
# Nearest to his: their, her, the, its, s, fiddlers, tomahawk, stoney,
# Nearest to with: between, by, in, for, quite, charlatans, lutheranism, deride,
# Nearest to seven: eight, five, nine, four, six, three, zero, two,
# Nearest to than: single, ohrid, adolphe, rescheduled, stirrups, flavianum, hadassah, conversations,
# Nearest to from: into, between, under, concise, customized, in, by, on,
# Nearest to s: his, christe, victorian, degrades, whose, mandated, oval, gustloff,
# Nearest to be: been, have, sepulchre, was, were, ytv, propagation, by,
# Average loss at step 22000: 3.551460
# Average loss at step 24000: 3.548549
# Average loss at step 26000: 3.503565
# Average loss at step 28000: 3.358695
# Average loss at step 30000: 3.471146
# Nearest to can: may, will, would, could, must, should, might, electrophoresis,
# Nearest to they: we, you, there, it, he, these, who, i,
# Nearest to so: trinity, waste, forks, notorious, lanzarote, if, dispossessed, intense,
# Nearest to after: before, during, when, doves, whispers, by, waldseem, bibliography,
# Nearest to the: its, any, this, their, some, his, a, evolutionists,
# Nearest to many: some, several, these, those, bose, various, much, valiantly,
# Nearest to between: with, from, gray, lamps, against, burial, kuna, under,
# Nearest to had: has, have, was, were, lubrication, got, durations, annan,
# Nearest to have: had, has, were, be, are, say, taekwondo, willson,
# Nearest to his: their, her, its, the, s, my, our, fiddlers,
# Nearest to with: between, by, and, on, toward, moore, hailie, for,
# Nearest to seven: five, eight, nine, four, six, three, zero, two,
# Nearest to than: or, adolphe, stirrups, much, rescheduled, hadassah, aberrant, gprs,
# Nearest to from: into, educate, between, in, eelam, under, within, on,
# Nearest to s: whose, degrades, his, longman, cuneiform, inducted, unleashing, bitterly,
# Nearest to be: have, been, by, being, propagation, is, were, become,
# Average loss at step 32000: 3.466601
# Average loss at step 34000: 3.484372
# Average loss at step 36000: 3.479916
# Average loss at step 38000: 3.375332
# Average loss at step 40000: 3.407078
# Nearest to can: may, will, would, could, must, should, might, cannot,
# Nearest to they: he, we, there, you, she, who, it, i,
# Nearest to so: trinity, forks, if, malabo, seti, lanzarote, notorious, bags,
# Nearest to after: before, when, during, while, gacy, through, doves, deviant,
# Nearest to the: its, their, his, this, quetzalcoatl, a, foosball, bt,
# Nearest to many: some, several, these, various, both, much, those, other,
# Nearest to between: with, from, under, against, lamps, rushing, through, fusiliers,
# Nearest to had: has, have, was, were, annan, lubrication, robbing, having,
# Nearest to have: had, has, be, were, are, willson, tend, taxpayers,
# Nearest to his: their, her, its, my, the, your, our, s,
# Nearest to with: between, straightening, salutation, belarusian, gershom, hailie, magnificent, against,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to than: adolphe, much, stirrups, flex, alternatives, respective, rescheduled, aberrant,
# Nearest to from: into, between, under, concise, through, in, during, by,
# Nearest to s: whose, workability, walker, chorale, his, sizeable, valve, isbn,
# Nearest to be: have, been, being, were, was, propagation, become, are,
# Average loss at step 42000: 3.464442
# Average loss at step 44000: 3.449737
# Average loss at step 46000: 3.465212
# Average loss at step 48000: 3.426336
# Average loss at step 50000: 3.415355
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to they: we, there, you, he, she, i, not, it,
# Nearest to so: if, conventionally, seti, forks, malabo, denominated, trinity, thicker,
# Nearest to after: before, during, when, while, although, under, until, despite,
# Nearest to the: its, their, a, this, any, some, each, toei,
# Nearest to many: some, several, these, various, most, such, both, those,
# Nearest to between: with, from, in, against, lamps, through, among, degenerate,
# Nearest to had: has, have, was, were, received, saw, robbing, annan,
# Nearest to have: had, has, were, are, taxpayers, be, tend, willson,
# Nearest to his: their, her, its, my, our, simulates, spectacle, your,
# Nearest to with: between, by, drinker, including, toward, adr, into, against,
# Nearest to seven: eight, six, four, five, nine, three, zero, one,
# Nearest to than: much, or, respective, adolphe, but, alternatives, rescheduled, complicated,
# Nearest to from: through, under, into, in, segr, between, suu, baserunner,
# Nearest to s: victorian, whose, chadwick, simplify, pour, sulfates, his, valve,
# Nearest to be: been, become, have, refer, ytv, was, is, being,
# Average loss at step 52000: 3.265135
# Average loss at step 54000: 3.277839
# Average loss at step 56000: 3.428513
# Average loss at step 58000: 3.412022
# Average loss at step 60000: 3.375038
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to they: we, there, he, you, it, she, these, fatalities,
# Nearest to so: if, forks, conventionally, malabo, thicker, dogg, then, cpus,
# Nearest to after: before, during, when, while, until, without, if, under,
# Nearest to the: their, any, its, a, this, some, these, evolutionists,
# Nearest to many: some, several, these, various, most, all, such, those,
# Nearest to between: with, among, from, through, lamps, in, against, veitch,
# Nearest to had: has, have, was, saw, were, received, wanted, gave,
# Nearest to have: had, has, were, are, be, tend, willson, taxpayers,
# Nearest to his: her, their, its, my, our, the, your, unfettered,
# Nearest to with: between, toward, while, against, seeming, straightening, among, hailie,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to than: much, complicated, or, adolphe, but, sonnet, stirrups, bonzo,
# Nearest to from: through, into, between, in, under, isostatic, suu, within,
# Nearest to s: whose, majin, unleashing, creative, fred, kennedy, lab, pour,
# Nearest to be: been, is, were, become, being, have, refer, are,
# Average loss at step 62000: 3.395805
# Average loss at step 64000: 3.366957
# Average loss at step 66000: 3.334979
# Average loss at step 68000: 3.364887
# Average loss at step 70000: 3.393278
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to they: we, he, there, you, it, she, who, fatalities,
# Nearest to so: then, if, before, squads, copernican, conventionally, forks, too,
# Nearest to after: before, during, when, while, without, despite, though, until,
# Nearest to the: his, a, its, their, maguey, this, teaming, liquefied,
# Nearest to many: some, several, these, various, most, numerous, all, those,
# Nearest to between: among, with, from, over, through, against, lamps, within,
# Nearest to had: has, have, were, was, saw, wanted, been, having,
# Nearest to have: had, has, were, are, be, tend, pelvis, taxpayers,
# Nearest to his: her, their, its, my, your, our, the, arabia,
# Nearest to with: between, when, hailie, or, including, budo, monetarist, gah,
# Nearest to seven: six, eight, five, four, three, nine, zero, two,
# Nearest to than: much, complicated, adolphe, but, or, while, stirrups, flex,
# Nearest to from: into, through, under, within, between, ism, during, in,
# Nearest to s: isbn, walker, whose, sizeable, kh, repose, feb, encyclopedist,
# Nearest to be: been, were, being, become, have, are, refer, is,
# Average loss at step 72000: 3.424728
# Average loss at step 74000: 3.422326
# Average loss at step 76000: 3.403359
# Average loss at step 78000: 3.367792
# Average loss at step 80000: 3.375952
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to they: we, there, he, you, it, she, indefinite, not,
# Nearest to so: if, copernican, then, too, conventionally, before, turns, climbed,
# Nearest to after: before, during, when, while, without, unwavering, until, despite,
# Nearest to the: its, this, a, his, their, each, quetzalcoatl, any,
# Nearest to many: several, some, these, various, all, numerous, most, few,
# Nearest to between: with, in, among, against, within, through, under, from,
# Nearest to had: has, have, was, were, having, began, saw, wanted,
# Nearest to have: had, has, were, tend, be, are, taxpayers, provide,
# Nearest to his: her, their, its, my, our, your, the, buffering,
# Nearest to with: between, including, toward, hailie, seeming, budo, by, depicts,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to than: complicated, much, or, but, adolphe, sonnet, bass, leveling,
# Nearest to from: into, through, under, across, during, fusiliers, between, isostatic,
# Nearest to s: whose, his, walker, shalt, ifr, feb, khagan, sulfates,
# Nearest to be: been, was, become, being, have, is, ytv, refer,
# Average loss at step 82000: 3.411651
# Average loss at step 84000: 3.270496
# Average loss at step 86000: 3.372605
# Average loss at step 88000: 3.254331
# Average loss at step 90000: 3.370784
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to they: we, there, he, you, she, it, never, i,
# Nearest to so: then, if, too, tow, thus, conventionally, copernican, malabo,
# Nearest to after: before, during, when, without, while, unwavering, gacy, despite,
# Nearest to the: his, a, their, its, hammered, her, this, our,
# Nearest to many: several, some, various, these, numerous, all, few, those,
# Nearest to between: among, with, against, viceroyalty, through, in, lamps, across,
# Nearest to had: has, have, was, were, having, is, would, since,
# Nearest to have: had, has, tend, were, include, are, be, willson,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to with: between, including, by, magnificent, when, klister, enfants, seeming,
# Nearest to seven: eight, five, six, four, nine, three, zero, two,
# Nearest to than: complicated, or, much, but, sonnet, usr, wissowa, adolphe,
# Nearest to from: in, into, through, across, within, under, during, baserunner,
# Nearest to s: whose, his, the, juggalo, eighties, my, and, abusive,
# Nearest to be: been, become, being, have, was, were, are, refer,
# Average loss at step 92000: 3.353571
# Average loss at step 94000: 3.330063
# Average loss at step 96000: 3.364737
# Average loss at step 98000: 3.354856
# Average loss at step 100000: 3.238776
# Nearest to can: could, may, will, would, should, must, cannot, might,
# Nearest to they: we, there, he, you, she, it, these, who,
# Nearest to so: if, too, tow, incremental, conventionally, recession, fact, arianespace,
# Nearest to after: before, during, when, without, despite, while, under, although,
# Nearest to the: its, their, a, envious, this, s, his, and,
# Nearest to many: several, some, these, various, numerous, all, most, those,
# Nearest to between: among, with, against, across, through, from, within, viceroyalty,
# Nearest to had: has, have, was, were, having, suggested, since, wanted,
# Nearest to have: had, has, tend, were, are, include, provide, be,
# Nearest to his: her, their, its, my, your, our, ducati, the,
# Nearest to with: between, including, monetarist, within, against, drinker, in, by,
# Nearest to seven: six, five, eight, four, nine, three, zero, two,
# Nearest to than: complicated, much, sonnet, usr, wissowa, avram, but, adolphe,
# Nearest to from: into, through, within, across, in, between, of, geophysical,
# Nearest to s: whose, feb, the, molson, eighties, bandy, victorian, interscope,
# Nearest to be: been, become, have, being, was, refer, remain, deutsche,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
